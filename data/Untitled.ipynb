# %%
import pandas as pd

# %%
df=pd.read_csv('matchup_data.csv')

# %%
df.head(100)
# Out:
#       match_id          Radiant             Dire  radiant_winner  \
# 0   4061660411           Fnatic      Team Liquid               0
# 1   4061662358    Evil Geniuses      VGJ Thunder               1
# 2   4061671194               OG          PSG.LGD               0
# 3   4061694810          Mineski  Invictus Gaming               0
# 4   4061721528               OG          PSG.LGD               1
# 5   4061742840           Fnatic      Team Liquid               1
# 6   4061745637    Evil Geniuses      VGJ Thunder               1
# 7   4061766981          Mineski  Invictus Gaming               1
# 8   4061802430     OpTic Gaming       Virtus.pro               0
# 9   4061804100        VGJ Storm      Vici Gaming               1
# 10  4061815647      Team Secret    Team Serenity               0
# 11  4061848287     TNC Predator           Newbee               0
# 12  4061858332        VGJ Storm      Vici Gaming               1
# ...
