# %%
import dota2api
import numpy as np
import pandas as pd

# %%
api = dota2api.Initialise("B335AEF628EF2F2D2DC5A94BA4A02ED9")

mf=api.get_match_details(3968147656)

# %%
mf
# Out:
# {'players': [{'account_id': 63703276,
#    'player_slot': 0,
#    'hero_id': 106,
#    'item_0': 133,
#    'item_1': 145,
#    'item_2': 256,
#    'item_3': 133,
#    'item_4': 48,
#    'item_5': 141,
#    'backpack_0': 41,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 13,
#    'deaths': 8,
#    'assists': 31,
#    'leaver_status': 0,
#    'last_hits': 633,
#    'denies': 19,
#    'gold_per_min': 807,
#    'xp_per_min': 665,
#    'level': 25,
#    'hero_damage': 62026,
#    'tower_damage': 5262,
#    'hero_healing': 400,
#    'gold': 8331,
#    'gold_spent': 36475,
#    'scaled_hero_damage': 31197,
#    'scaled_tower_damage': 3038,
#    'scaled_hero_healing': 229,
#    'ability_upgrades': [{'ability': 5605, 'time': 645, 'level': 1},
#     {'ability': 5603, 'time': 761, 'level': 2},
#     {'ability': 5605, 'time': 854, 'level': 3},
#     {'ability': 5603, 'time': 999, 'level': 4},
#     {'ability': 5605, 'time': 1079, 'level': 5},
#     {'ability': 5606, 'time': 1206, 'level': 6},
#     {'ability': 5605, 'time': 1271, 'level': 7},
#     {'ability': 5604, 'time': 1356, 'level': 8},
#     {'ability': 5603, 'time': 1407, 'level': 9},
#     {'ability': 6172, 'time': 1538, 'level': 10},
#     {'ability': 5603, 'time': 1661, 'level': 11},
#     {'ability': 5604, 'time': 1720, 'level': 12},
#     {'ability': 5604, 'time': 1775, 'level': 13},
#     {'ability': 5604, 'time': 1887, 'level': 14},
#     {'ability': 6176, 'time': 2021, 'level': 15},
#     {'ability': 5606, 'time': 2044, 'level': 16},
#     {'ability': 5606, 'time': 2169, 'level': 17},
#     {'ability': 5989, 'time': 2368, 'level': 18},
#     {'ability': 7050, 'time': 3112, 'level': 19}],
#    'hero_name': 'Ember Spirit',
#    'item_0_name': 'Divine Rapier',
#    'item_1_name': 'Battle Fury',
#    'item_3_name': 'Divine Rapier',
#    'item_4_name': 'Boots of Travel',
#    'item_5_name': 'Daedalus',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 440063476,
#    'player_slot': 1,
#    'hero_id': 37,
#    'item_0': 108,
#    'item_1': 254,
#    'item_2': 180,
#    'item_3': 36,
#    'item_4': 46,
#    'item_5': 218,
#    'backpack_0': 40,
#    'backpack_1': 0,
#    'backpack_2': 188,
#    'kills': 6,
#    'deaths': 8,
#    'assists': 27,
#    'leaver_status': 0,
#    'last_hits': 94,
#    'denies': 4,
#    'gold_per_min': 317,
#    'xp_per_min': 564,
#    'level': 25,
#    'hero_damage': 20448,
#    'tower_damage': 1949,
#    'hero_healing': 13710,
#    'gold': 2228,
#    'gold_spent': 16085,
#    'scaled_hero_damage': 14058,
#    'scaled_tower_damage': 1032,
#    'scaled_hero_healing': 10089,
#    'ability_upgrades': [{'ability': 5163, 'time': 648, 'level': 1},
#     {'ability': 5162, 'time': 763, 'level': 2},
#     {'ability': 5163, 'time': 935, 'level': 3},
#     {'ability': 5162, 'time': 1079, 'level': 4},
#     {'ability': 5163, 'time': 1154, 'level': 5},
#     {'ability': 5165, 'time': 1256, 'level': 6},
#     {'ability': 5163, 'time': 1419, 'level': 7},
#     {'ability': 5164, 'time': 1508, 'level': 8},
#     {'ability': 5164, 'time': 1614, 'level': 9},
#     {'ability': 6056, 'time': 1790, 'level': 10},
#     {'ability': 5164, 'time': 1845, 'level': 11},
#     {'ability': 5165, 'time': 2048, 'level': 12},
#     {'ability': 5164, 'time': 2059, 'level': 13},
#     {'ability': 5162, 'time': 2157, 'level': 14},
#     {'ability': 7125, 'time': 2213, 'level': 15},
#     {'ability': 5162, 'time': 2287, 'level': 16},
#     {'ability': 5165, 'time': 2581, 'level': 17},
#     {'ability': 6505, 'time': 2983, 'level': 18},
#     {'ability': 6053, 'time': 3731, 'level': 19}],
#    'hero_name': 'Warlock',
#    'item_0_name': "Aghanim's Scepter",
#    'item_1_name': 'Glimmer Cape',
#    'item_2_name': 'Arcane Boots',
#    'item_3_name': 'Magic Wand',
#    'item_4_name': 'Town Portal Scroll',
#    'item_5_name': 'Observer and Sentry Wards',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 192434647,
#    'player_slot': 2,
#    'hero_id': 103,
#    'item_0': 90,
#    'item_1': 127,
#    'item_2': 100,
#    'item_3': 223,
#    'item_4': 48,
#    'item_5': 129,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 10,
#    'deaths': 7,
#    'assists': 17,
#    'leaver_status': 1,
#    'last_hits': 210,
#    'denies': 17,
#    'gold_per_min': 433,
#    'xp_per_min': 553,
#    'level': 25,
#    'hero_damage': 24454,
#    'tower_damage': 3183,
#    'hero_healing': 155,
#    'gold': 2810,
#    'gold_spent': 19265,
#    'scaled_hero_damage': 15040,
#    'scaled_tower_damage': 2068,
#    'scaled_hero_healing': 48,
#    'ability_upgrades': [{'ability': 5591, 'time': 662, 'level': 1},
#     {'ability': 5589, 'time': 760, 'level': 2},
#     {'ability': 5589, 'time': 897, 'level': 3},
#     {'ability': 5593, 'time': 1023, 'level': 4},
#     {'ability': 5589, 'time': 1095, 'level': 5},
#     {'ability': 5593, 'time': 1215, 'level': 6},
#     {'ability': 5589, 'time': 1364, 'level': 7},
#     {'ability': 5593, 'time': 1502, 'level': 8},
#     {'ability': 5594, 'time': 1574, 'level': 9},
#     {'ability': 5959, 'time': 1781, 'level': 10},
#     {'ability': 5593, 'time': 1897, 'level': 11},
#     {'ability': 5594, 'time': 2017, 'level': 12},
#     {'ability': 5591, 'time': 2046, 'level': 13},
#     {'ability': 5591, 'time': 2175, 'level': 14},
#     {'ability': 6138, 'time': 2316, 'level': 15},
#     {'ability': 5591, 'time': 2515, 'level': 16},
#     {'ability': 5594, 'time': 2894, 'level': 17},
#     {'ability': 6378, 'time': 3202, 'level': 18},
#     {'ability': 6720, 'time': 3625, 'level': 19}],
#    'hero_name': 'Elder Titan',
#    'item_0_name': 'Pipe of Insight',
#    'item_1_name': 'Blade Mail',
#    'item_2_name': "Eul's Scepter of Divinity",
#    'item_4_name': 'Boots of Travel',
#    'item_5_name': 'Soul Booster',
#    'leaver_status_name': 'DISCONNECTED',
#    'leaver_status_description': 'player DC, no abandon'},
#   {'account_id': 298938658,
#    'player_slot': 3,
#    'hero_id': 46,
#    'item_0': 48,
#    'item_1': 225,
#    'item_2': 250,
#    'item_3': 116,
#    'item_4': 168,
#    'item_5': 1,
#    'backpack_0': 0,
#    'backpack_1': 46,
#    'backpack_2': 256,
#    'kills': 15,
#    'deaths': 8,
#    'assists': 15,
#    'leaver_status': 0,
#    'last_hits': 568,
#    'denies': 25,
#    'gold_per_min': 720,
#    'xp_per_min': 606,
#    'level': 25,
#    'hero_damage': 35751,
#    'tower_damage': 8602,
#    'hero_healing': 0,
#    'gold': 4785,
#    'gold_spent': 31075,
#    'scaled_hero_damage': 24338,
#    'scaled_tower_damage': 5635,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5196, 'time': 701, 'level': 1},
#     {'ability': 5194, 'time': 740, 'level': 2},
#     {'ability': 5194, 'time': 782, 'level': 3},
#     {'ability': 5196, 'time': 840, 'level': 4},
#     {'ability': 5194, 'time': 928, 'level': 5},
#     {'ability': 5197, 'time': 1009, 'level': 6},
#     {'ability': 5194, 'time': 1082, 'level': 7},
#     {'ability': 5195, 'time': 1137, 'level': 8},
#     {'ability': 5195, 'time': 1226, 'level': 9},
#     {'ability': 6016, 'time': 1293, 'level': 10},
#     {'ability': 5196, 'time': 1376, 'level': 11},
#     {'ability': 5196, 'time': 1439, 'level': 12},
#     {'ability': 5195, 'time': 1537, 'level': 13},
#     {'ability': 5195, 'time': 1584, 'level': 14},
#     {'ability': 6938, 'time': 1665, 'level': 15},
#     {'ability': 5197, 'time': 1780, 'level': 16},
#     {'ability': 5197, 'time': 2034, 'level': 17},
#     {'ability': 6545, 'time': 2385, 'level': 18},
#     {'ability': 6071, 'time': 3353, 'level': 19}],
#    'hero_name': 'Templar Assassin',
#    'item_0_name': 'Boots of Travel',
#    'item_2_name': 'Bloodthorn',
#    'item_3_name': 'Black King Bar',
#    'item_4_name': 'Desolator',
#    'item_5_name': 'Blink Dagger',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 474762217,
#    'player_slot': 4,
#    'hero_id': 101,
#    'item_0': 57,
#    'item_1': 206,
#    'item_2': 256,
#    'item_3': 190,
#    'item_4': 102,
#    'item_5': 29,
#    'backpack_0': 260,
#    'backpack_1': 46,
#    'backpack_2': 0,
#    'kills': 17,
#    'deaths': 11,
#    'assists': 16,
#    'leaver_status': 0,
#    'last_hits': 74,
#    'denies': 3,
#    'gold_per_min': 366,
#    'xp_per_min': 466,
#    'level': 25,
#    'hero_damage': 25990,
#    'tower_damage': 371,
#    'hero_healing': 0,
#    'gold': 5180,
#    'gold_spent': 15325,
#    'scaled_hero_damage': 21166,
#    'scaled_tower_damage': 228,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5581, 'time': 660, 'level': 1},
#     {'ability': 5582, 'time': 759, 'level': 2},
#     {'ability': 5582, 'time': 871, 'level': 3},
#     {'ability': 5583, 'time': 1017, 'level': 4},
#     {'ability': 5582, 'time': 1212, 'level': 5},
#     {'ability': 5583, 'time': 1321, 'level': 6},
#     {'ability': 5584, 'time': 1356, 'level': 7},
#     {'ability': 5582, 'time': 1486, 'level': 8},
#     {'ability': 5583, 'time': 1575, 'level': 9},
#     {'ability': 5583, 'time': 1720, 'level': 10},
#     {'ability': 5581, 'time': 1891, 'level': 11},
#     {'ability': 5584, 'time': 2017, 'level': 12},
#     {'ability': 5919, 'time': 2027, 'level': 13},
#     {'ability': 5581, 'time': 2131, 'level': 14},
#     {'ability': 6884, 'time': 2195, 'level': 15},
#     {'ability': 5581, 'time': 2269, 'level': 16},
#     {'ability': 5584, 'time': 2849, 'level': 17},
#     {'ability': 6886, 'time': 3208, 'level': 18},
#     {'ability': 6318, 'time': 4182, 'level': 19}],
#    'hero_name': 'Skywrath Mage',
#    'item_0_name': 'Void Stone',
#    'item_1_name': 'Rod of Atos',
#    'item_3_name': 'Veil of Discord',
#    'item_4_name': 'Force Staff',
#    'item_5_name': 'Boots of Speed',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 174225518,
#    'player_slot': 128,
#    'hero_id': 2,
#    'item_0': 127,
#    'item_1': 1,
#    'item_2': 116,
#    'item_3': 214,
#    'item_4': 256,
#    'item_5': 125,
#    'backpack_0': 152,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 12,
#    'deaths': 15,
#    'assists': 21,
#    'leaver_status': 0,
#    'last_hits': 225,
#    'denies': 0,
#    'gold_per_min': 469,
#    'xp_per_min': 586,
#    'level': 25,
#    'hero_damage': 27600,
#    'tower_damage': 55,
#    'hero_healing': 110,
#    'gold': 2942,
#    'gold_spent': 19760,
#    'scaled_hero_damage': 20558,
#    'scaled_tower_damage': 39,
#    'scaled_hero_healing': 217,
#    'ability_upgrades': [{'ability': 5008, 'time': 644, 'level': 1},
#     {'ability': 5009, 'time': 764, 'level': 2},
#     {'ability': 5007, 'time': 908, 'level': 3},
#     {'ability': 5009, 'time': 1047, 'level': 4},
#     {'ability': 5008, 'time': 1206, 'level': 5},
#     {'ability': 5010, 'time': 1259, 'level': 6},
#     {'ability': 5009, 'time': 1407, 'level': 7},
#     {'ability': 5009, 'time': 1522, 'level': 8},
#     {'ability': 5008, 'time': 1637, 'level': 9},
#     {'ability': 5982, 'time': 1737, 'level': 10},
#     {'ability': 5007, 'time': 1823, 'level': 11},
#     {'ability': 5010, 'time': 1894, 'level': 12},
#     {'ability': 5007, 'time': 1959, 'level': 13},
#     {'ability': 5007, 'time': 2020, 'level': 14},
#     {'ability': 6093, 'time': 2113, 'level': 15},
#     {'ability': 5008, 'time': 2190, 'level': 16},
#     {'ability': 5010, 'time': 2636, 'level': 17},
#     {'ability': 6079, 'time': 2982, 'level': 18},
#     {'ability': 6102, 'time': 3671, 'level': 19}],
#    'hero_name': 'Axe',
#    'item_0_name': 'Blade Mail',
#    'item_1_name': 'Blink Dagger',
#    'item_2_name': 'Black King Bar',
#    'item_3_name': 'Tranquil Boots',
#    'item_5_name': 'Vanguard',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 185470365,
#    'player_slot': 129,
#    'hero_id': 74,
#    'item_0': 263,
#    'item_1': 119,
#    'item_2': 0,
#    'item_3': 110,
#    'item_4': 116,
#    'item_5': 108,
#    'backpack_0': 46,
#    'backpack_1': 63,
#    'backpack_2': 235,
#    'kills': 12,
#    'deaths': 4,
#    'assists': 17,
#    'leaver_status': 0,
#    'last_hits': 520,
#    'denies': 13,
#    'gold_per_min': 606,
#    'xp_per_min': 615,
#    'level': 25,
#    'hero_damage': 29253,
#    'tower_damage': 2589,
#    'hero_healing': 0,
#    'gold': 1495,
#    'gold_spent': 32710,
#    'scaled_hero_damage': 15458,
#    'scaled_tower_damage': 1572,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5372, 'time': 596, 'level': 1},
#     {'ability': 5370, 'time': 733, 'level': 2},
#     {'ability': 5370, 'time': 792, 'level': 3},
#     {'ability': 5372, 'time': 874, 'level': 4},
#     {'ability': 5372, 'time': 963, 'level': 5},
#     {'ability': 5371, 'time': 1037, 'level': 6},
#     {'ability': 5372, 'time': 1150, 'level': 7},
#     {'ability': 5370, 'time': 1258, 'level': 8},
#     {'ability': 5372, 'time': 1330, 'level': 9},
#     {'ability': 5370, 'time': 1429, 'level': 10},
#     {'ability': 5372, 'time': 1617, 'level': 11},
#     {'ability': 5370, 'time': 1693, 'level': 12},
#     {'ability': 5372, 'time': 1849, 'level': 13},
#     {'ability': 5371, 'time': 1919, 'level': 14},
#     {'ability': 6811, 'time': 1970, 'level': 15},
#     {'ability': 6097, 'time': 2106, 'level': 16},
#     {'ability': 5371, 'time': 2195, 'level': 17},
#     {'ability': 5370, 'time': 2266, 'level': 18},
#     {'ability': 5371, 'time': 2479, 'level': 19},
#     {'ability': 6656, 'time': 2538, 'level': 20},
#     {'ability': 5370, 'time': 2668, 'level': 21},
#     {'ability': 5371, 'time': 2837, 'level': 22},
#     {'ability': 5371, 'time': 3034, 'level': 23},
#     {'ability': 5371, 'time': 3242, 'level': 24},
#     {'ability': 6098, 'time': 3309, 'level': 25}],
#    'hero_name': 'Invoker',
#    'item_0_name': 'Hurricane Pike',
#    'item_1_name': "Shiva's Guard",
#    'item_3_name': 'Refresher Orb',
#    'item_4_name': 'Black King Bar',
#    'item_5_name': "Aghanim's Scepter",
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 336251299,
#    'player_slot': 130,
#    'hero_id': 10,
#    'item_0': 156,
#    'item_1': 123,
#    'item_2': 139,
#    'item_3': 116,
#    'item_4': 176,
#    'item_5': 147,
#    'backpack_0': 63,
#    'backpack_1': 41,
#    'backpack_2': 0,
#    'kills': 10,
#    'deaths': 7,
#    'assists': 12,
#    'leaver_status': 1,
#    'last_hits': 631,
#    'denies': 18,
#    'gold_per_min': 697,
#    'xp_per_min': 751,
#    'level': 25,
#    'hero_damage': 31168,
#    'tower_damage': 1982,
#    'hero_healing': 0,
#    'gold': 3,
#    'gold_spent': 34850,
#    'scaled_hero_damage': 17627,
#    'scaled_tower_damage': 1434,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5055, 'time': 598, 'level': 1},
#     {'ability': 5052, 'time': 768, 'level': 2},
#     {'ability': 5055, 'time': 861, 'level': 3},
#     {'ability': 5053, 'time': 959, 'level': 4},
#     {'ability': 5055, 'time': 1084, 'level': 5},
#     {'ability': 5053, 'time': 1150, 'level': 6},
#     {'ability': 5055, 'time': 1202, 'level': 7},
#     {'ability': 5053, 'time': 1287, 'level': 8},
#     {'ability': 5053, 'time': 1333, 'level': 9},
#     {'ability': 6029, 'time': 1416, 'level': 10},
#     {'ability': 5057, 'time': 1494, 'level': 11},
#     {'ability': 5057, 'time': 1544, 'level': 12},
#     {'ability': 5052, 'time': 1627, 'level': 13},
#     {'ability': 5052, 'time': 1737, 'level': 14},
#     {'ability': 7060, 'time': 1920, 'level': 15},
#     {'ability': 5052, 'time': 1966, 'level': 16},
#     {'ability': 5057, 'time': 2049, 'level': 17},
#     {'ability': 6840, 'time': 2273, 'level': 18},
#     {'ability': 7052, 'time': 2838, 'level': 19}],
#    'hero_name': 'Morphling',
#    'item_0_name': 'Satanic',
#    'item_1_name': "Linken's Sphere",
#    'item_2_name': 'Butterfly',
#    'item_3_name': 'Black King Bar',
#    'item_4_name': 'Ethereal Blade',
#    'item_5_name': 'Manta Style',
#    'leaver_status_name': 'DISCONNECTED',
#    'leaver_status_description': 'player DC, no abandon'},
#   {'account_id': 112606998,
#    'player_slot': 131,
#    'hero_id': 119,
#    'item_0': 100,
#    'item_1': 1,
#    'item_2': 152,
#    'item_3': 180,
#    'item_4': 37,
#    'item_5': 210,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 5,
#    'deaths': 17,
#    'assists': 15,
#    'leaver_status': 0,
#    'last_hits': 135,
#    'denies': 16,
#    'gold_per_min': 395,
#    'xp_per_min': 383,
#    'level': 23,
#    'hero_damage': 21136,
#    'tower_damage': 0,
#    'hero_healing': 0,
#    'gold': 1626,
#    'gold_spent': 19270,
#    'scaled_hero_damage': 17517,
#    'scaled_tower_damage': 0,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 6342, 'time': 647, 'level': 1},
#     {'ability': 6341, 'time': 784, 'level': 2},
#     {'ability': 6339, 'time': 895, 'level': 3},
#     {'ability': 6341, 'time': 1020, 'level': 4},
#     {'ability': 6341, 'time': 1141, 'level': 5},
#     {'ability': 6340, 'time': 1333, 'level': 6},
#     {'ability': 6341, 'time': 1423, 'level': 7},
#     {'ability': 6342, 'time': 1456, 'level': 8},
#     {'ability': 6339, 'time': 1484, 'level': 9},
#     {'ability': 5939, 'time': 1579, 'level': 10},
#     {'ability': 6339, 'time': 1700, 'level': 11},
#     {'ability': 6340, 'time': 1807, 'level': 12},
#     {'ability': 6342, 'time': 1909, 'level': 13},
#     {'ability': 6342, 'time': 2009, 'level': 14},
#     {'ability': 6007, 'time': 2180, 'level': 15},
#     {'ability': 6339, 'time': 2348, 'level': 16},
#     {'ability': 6340, 'time': 2754, 'level': 17},
#     {'ability': 6464, 'time': 3109, 'level': 18}],
#    'item_0_name': "Eul's Scepter of Divinity",
#    'item_1_name': 'Blink Dagger',
#    'item_2_name': 'Shadow Blade',
#    'item_3_name': 'Arcane Boots',
#    'item_4_name': 'Ghost Scepter',
#    'item_5_name': "Heaven's Halberd",
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 117816091,
#    'player_slot': 132,
#    'hero_id': 27,
#    'item_0': 218,
#    'item_1': 180,
#    'item_2': 46,
#    'item_3': 1,
#    'item_4': 254,
#    'item_5': 36,
#    'backpack_0': 0,
#    'backpack_1': 244,
#    'backpack_2': 0,
#    'kills': 3,
#    'deaths': 21,
#    'assists': 15,
#    'leaver_status': 0,
#    'last_hits': 122,
#    'denies': 4,
#    'gold_per_min': 312,
#    'xp_per_min': 466,
#    'level': 25,
#    'hero_damage': 8992,
#    'tower_damage': 4478,
#    'hero_healing': 0,
#    'gold': 1735,
#    'gold_spent': 13260,
#    'scaled_hero_damage': 5420,
#    'scaled_tower_damage': 2640,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5080, 'time': 723, 'level': 1},
#     {'ability': 5078, 'time': 768, 'level': 2},
#     {'ability': 5078, 'time': 933, 'level': 3},
#     {'ability': 5079, 'time': 1271, 'level': 4},
#     {'ability': 5078, 'time': 1331, 'level': 5},
#     {'ability': 5081, 'time': 1450, 'level': 6},
#     {'ability': 5078, 'time': 1639, 'level': 7},
#     {'ability': 5079, 'time': 1908, 'level': 8},
#     {'ability': 5079, 'time': 1989, 'level': 9},
#     {'ability': 6017, 'time': 2129, 'level': 10},
#     {'ability': 5080, 'time': 2221, 'level': 11},
#     {'ability': 5081, 'time': 2367, 'level': 12},
#     {'ability': 5079, 'time': 2523, 'level': 13},
#     {'ability': 5080, 'time': 2859, 'level': 14},
#     {'ability': 6197, 'time': 2953, 'level': 15},
#     {'ability': 5080, 'time': 2979, 'level': 16},
#     {'ability': 5081, 'time': 3229, 'level': 17},
#     {'ability': 6295, 'time': 3322, 'level': 18},
#     {'ability': 6521, 'time': 4206, 'level': 19}],
#    'hero_name': 'Shadow Shaman',
#    'item_0_name': 'Observer and Sentry Wards',
#    'item_1_name': 'Arcane Boots',
#    'item_2_name': 'Town Portal Scroll',
#    'item_3_name': 'Blink Dagger',
#    'item_4_name': 'Glimmer Cape',
#    'item_5_name': 'Magic Wand',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'}],
#  'radiant_win': True,
#  'duration': 3603,
#  'pre_game_duration': 90,
#  'start_time': 1529739515,
#  'match_id': 3968147656,
#  'match_seq_num': 3442741946,
#  'tower_status_radiant': 1572,
#  'tower_status_dire': 0,
#  'barracks_status_radiant': 15,
#  'barracks_status_dire': 16,
#  'cluster': 183,
#  'first_blood_time': 8,
#  'lobby_type': 1,
#  'human_players': 10,
#  'leagueid': 3216,
#  'positive_votes': 0,
#  'negative_votes': 1,
#  'game_mode': 2,
#  'flags': 1,
#  'engine': 1,
#  'radiant_score': 64,
#  'dire_score': 42,
#  'radiant_team_id': 3741206,
#  'radiant_name': 'Nirvana.kz',
#  'radiant_logo': 2139095039,
#  'radiant_team_complete': 0,
#  'dire_team_id': 5023621,
#  'dire_name': 'Aktau je est',
#  'dire_logo': 858354911722404948,
#  'dire_team_complete': 0,
#  'radiant_captain': 63703276,
#  'dire_captain': 174225518,
#  'picks_bans': [{'is_pick': False, 'hero_id': 16, 'team': 0, 'order': 0},
#   {'is_pick': False, 'hero_id': 69, 'team': 1, 'order': 1},
#   {'is_pick': False, 'hero_id': 51, 'team': 0, 'order': 2},
#   {'is_pick': False, 'hero_id': 53, 'team': 1, 'order': 3},
#   {'is_pick': False, 'hero_id': 7, 'team': 0, 'order': 4},
#   {'is_pick': False, 'hero_id': 3, 'team': 1, 'order': 5},
#   {'is_pick': True, 'hero_id': 101, 'team': 0, 'order': 6},
#   {'is_pick': True, 'hero_id': 119, 'team': 1, 'order': 7},
#   {'is_pick': True, 'hero_id': 2, 'team': 1, 'order': 8},
#   {'is_pick': True, 'hero_id': 103, 'team': 0, 'order': 9},
#   {'is_pick': False, 'hero_id': 47, 'team': 0, 'order': 10},
#   {'is_pick': False, 'hero_id': 38, 'team': 1, 'order': 11},
#   {'is_pick': False, 'hero_id': 12, 'team': 0, 'order': 12},
#   {'is_pick': False, 'hero_id': 78, 'team': 1, 'order': 13},
#   {'is_pick': True, 'hero_id': 27, 'team': 1, 'order': 14},
#   {'is_pick': True, 'hero_id': 37, 'team': 0, 'order': 15},
#   {'is_pick': True, 'hero_id': 74, 'team': 1, 'order': 16},
#   {'is_pick': True, 'hero_id': 106, 'team': 0, 'order': 17},
#   {'is_pick': False, 'hero_id': 41, 'team': 1, 'order': 18},
#   {'is_pick': False, 'hero_id': 93, 'team': 0, 'order': 19},
#   {'is_pick': True, 'hero_id': 46, 'team': 0, 'order': 20},
#   {'is_pick': True, 'hero_id': 10, 'team': 1, 'order': 21}],
#  'lobby_name': 'Practice',
#  'game_mode_name': 'Captains Mode',
#  'cluster_name': 'Russia'}

# %%
mf['barracks_status_radiant']
dire_assists=0

# %%
dire_assists+= mf['players'][0]['assists']
dire_assists
# Out:
# 4

# %%
dire_assists+= mf['players'][1]['assists']
dire_assists+= mf['players'][2]['assists']
dire_assists+= mf['players'][3]['assists']
dire_assists+= mf['players'][4]['assists']
dire_assists+= mf['players'][5]['assists']

# %%
dire_assists
# Out:
# 54
