# %%
import pandas as pd

# %%
df=pd.read_csv('full_data.csv')

# %%
df.head(100)
# Out:
#       match_id          Radiant             Dire  radiant_assists  \
# 0   4061660411           Fnatic      Team Liquid               80
# 1   4061662358    Evil Geniuses      VGJ Thunder              117
# 2   4061671194               OG          PSG.LGD               34
# 3   4061694810          Mineski  Invictus Gaming               41
# 4   4061721528               OG          PSG.LGD              103
# 5   4061742840           Fnatic      Team Liquid               91
# 6   4061745637    Evil Geniuses      VGJ Thunder               79
# 7   4061766981          Mineski  Invictus Gaming               77
# 8   4061802430     OpTic Gaming       Virtus.pro               56
# 9   4061804100        VGJ Storm      Vici Gaming               36
# 10  4061815647      Team Secret    Team Serenity               30
# 11  4061848287     TNC Predator           Newbee               24
# 12  4061858332        VGJ Storm      Vici Gaming               74
# ...
