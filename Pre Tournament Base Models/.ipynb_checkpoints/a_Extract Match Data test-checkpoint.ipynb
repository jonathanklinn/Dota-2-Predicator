# %%
import dota2api
import numpy as np
import pandas as pd

# %%
api = dota2api.Initialise("B335AEF628EF2F2D2DC5A94BA4A02ED9")

mf=api.get_match_details(3981626536)

# %%
mf
# Out:
# {'players': [{'account_id': 111030315,
#    'player_slot': 0,
#    'hero_id': 3,
#    'item_0': 46,
#    'item_1': 0,
#    'item_2': 31,
#    'item_3': 36,
#    'item_4': 29,
#    'item_5': 0,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 1,
#    'deaths': 6,
#    'assists': 10,
#    'leaver_status': 0,
#    'last_hits': 16,
#    'denies': 3,
#    'gold_per_min': 235,
#    'xp_per_min': 305,
#    'level': 12,
#    'hero_damage': 3218,
#    'tower_damage': 49,
#    'hero_healing': 0,
#    'gold': 1371,
#    'gold_spent': 4210,
#    'scaled_hero_damage': 2692,
#    'scaled_tower_damage': 22,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5011, 'time': 955, 'level': 1},
#     {'ability': 5014, 'time': 988, 'level': 2},
#     {'ability': 5011, 'time': 1089, 'level': 3},
#     {'ability': 5014, 'time': 1200, 'level': 4},
#     {'ability': 5011, 'time': 1373, 'level': 5},
#     {'ability': 5013, 'time': 1511, 'level': 6},
#     {'ability': 5011, 'time': 1624, 'level': 7},
#     {'ability': 5014, 'time': 1681, 'level': 8},
#     {'ability': 5014, 'time': 1856, 'level': 9},
#     {'ability': 6003, 'time': 2045, 'level': 10},
#     {'ability': 5012, 'time': 2282, 'level': 11}],
#    'hero_name': 'Bane',
#    'item_0_name': 'Town Portal Scroll',
#    'item_2_name': 'Cloak',
#    'item_3_name': 'Magic Wand',
#    'item_4_name': 'Boots of Speed',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 86802844,
#    'player_slot': 1,
#    'hero_id': 49,
#    'item_0': 178,
#    'item_1': 63,
#    'item_2': 36,
#    'item_3': 1,
#    'item_4': 98,
#    'item_5': 11,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 7,
#    'deaths': 2,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 107,
#    'denies': 9,
#    'gold_per_min': 469,
#    'xp_per_min': 537,
#    'level': 17,
#    'hero_damage': 9373,
#    'tower_damage': 2272,
#    'hero_healing': 0,
#    'gold': 1943,
#    'gold_spent': 9985,
#    'scaled_hero_damage': 8224,
#    'scaled_tower_damage': 1417,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5226, 'time': 900, 'level': 1},
#     {'ability': 5228, 'time': 917, 'level': 2},
#     {'ability': 5228, 'time': 976, 'level': 3},
#     {'ability': 5226, 'time': 1052, 'level': 4},
#     {'ability': 5226, 'time': 1186, 'level': 5},
#     {'ability': 5229, 'time': 1266, 'level': 6},
#     {'ability': 5227, 'time': 1387, 'level': 7},
#     {'ability': 5226, 'time': 1541, 'level': 8},
#     {'ability': 5228, 'time': 1667, 'level': 9},
#     {'ability': 7113, 'time': 1756, 'level': 10},
#     {'ability': 5228, 'time': 1826, 'level': 11},
#     {'ability': 5229, 'time': 1892, 'level': 12},
#     {'ability': 5227, 'time': 1982, 'level': 13},
#     {'ability': 5227, 'time': 2119, 'level': 14},
#     {'ability': 5939, 'time': 2174, 'level': 15},
#     {'ability': 5227, 'time': 2283, 'level': 16}],
#    'hero_name': 'Dragon Knight',
#    'item_0_name': 'Soul Ring',
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Blink Dagger',
#    'item_4_name': 'Orchid Malevolence',
#    'item_5_name': 'Quelling Blade',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 70388657,
#    'player_slot': 2,
#    'hero_id': 4,
#    'item_0': 212,
#    'item_1': 127,
#    'item_2': 36,
#    'item_3': 116,
#    'item_4': 11,
#    'item_5': 63,
#    'backpack_0': 0,
#    'backpack_1': 46,
#    'backpack_2': 0,
#    'kills': 6,
#    'deaths': 4,
#    'assists': 7,
#    'leaver_status': 0,
#    'last_hits': 161,
#    'denies': 19,
#    'gold_per_min': 493,
#    'xp_per_min': 529,
#    'level': 17,
#    'hero_damage': 11047,
#    'tower_damage': 677,
#    'hero_healing': 330,
#    'gold': 1832,
#    'gold_spent': 10200,
#    'scaled_hero_damage': 10228,
#    'scaled_tower_damage': 425,
#    'scaled_hero_healing': 90,
#    'ability_upgrades': [{'ability': 5015, 'time': 881, 'level': 1},
#     {'ability': 5017, 'time': 914, 'level': 2},
#     {'ability': 5017, 'time': 946, 'level': 3},
#     {'ability': 5016, 'time': 1065, 'level': 4},
#     {'ability': 5017, 'time': 1227, 'level': 5},
#     {'ability': 5018, 'time': 1286, 'level': 6},
#     {'ability': 5017, 'time': 1454, 'level': 7},
#     {'ability': 5016, 'time': 1502, 'level': 8},
#     {'ability': 5016, 'time': 1574, 'level': 9},
#     {'ability': 5933, 'time': 1634, 'level': 10},
#     {'ability': 5015, 'time': 1699, 'level': 11},
#     {'ability': 5018, 'time': 1798, 'level': 12},
#     {'ability': 5016, 'time': 1916, 'level': 13},
#     {'ability': 5015, 'time': 2008, 'level': 14},
#     {'ability': 6311, 'time': 2128, 'level': 15},
#     {'ability': 5015, 'time': 2287, 'level': 16}],
#    'hero_name': 'Bloodseeker',
#    'item_0_name': 'Ring of Aquila',
#    'item_1_name': 'Blade Mail',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Black King Bar',
#    'item_4_name': 'Quelling Blade',
#    'item_5_name': 'Power Treads',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 91460772,
#    'player_slot': 3,
#    'hero_id': 20,
#    'item_0': 36,
#    'item_1': 185,
#    'item_2': 244,
#    'item_3': 63,
#    'item_4': 46,
#    'item_5': 40,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 3,
#    'deaths': 5,
#    'assists': 18,
#    'leaver_status': 0,
#    'last_hits': 27,
#    'denies': 3,
#    'gold_per_min': 282,
#    'xp_per_min': 338,
#    'level': 13,
#    'hero_damage': 8364,
#    'tower_damage': 399,
#    'hero_healing': 0,
#    'gold': 1955,
#    'gold_spent': 5215,
#    'scaled_hero_damage': 6897,
#    'scaled_tower_damage': 232,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5124, 'time': 873, 'level': 1},
#     {'ability': 5122, 'time': 949, 'level': 2},
#     {'ability': 5124, 'time': 1055, 'level': 3},
#     {'ability': 5122, 'time': 1174, 'level': 4},
#     {'ability': 5123, 'time': 1329, 'level': 5},
#     {'ability': 5125, 'time': 1421, 'level': 6},
#     {'ability': 5124, 'time': 1722, 'level': 7},
#     {'ability': 5123, 'time': 1854, 'level': 8},
#     {'ability': 5123, 'time': 1956, 'level': 9},
#     {'ability': 5123, 'time': 2078, 'level': 10},
#     {'ability': 6138, 'time': 2184, 'level': 11},
#     {'ability': 5125, 'time': 2224, 'level': 12},
#     {'ability': 5122, 'time': 2287, 'level': 13}],
#    'hero_name': 'Vengeful Spirit',
#    'item_0_name': 'Magic Wand',
#    'item_1_name': 'Drum of Endurance',
#    'item_2_name': 'Wind Lace',
#    'item_3_name': 'Power Treads',
#    'item_4_name': 'Town Portal Scroll',
#    'item_5_name': 'Dust of Appearance',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 116881520,
#    'player_slot': 4,
#    'hero_id': 92,
#    'item_0': 29,
#    'item_1': 164,
#    'item_2': 242,
#    'item_3': 212,
#    'item_4': 187,
#    'item_5': 90,
#    'backpack_0': 0,
#    'backpack_1': 38,
#    'backpack_2': 0,
#    'kills': 11,
#    'deaths': 2,
#    'assists': 12,
#    'leaver_status': 0,
#    'last_hits': 139,
#    'denies': 17,
#    'gold_per_min': 574,
#    'xp_per_min': 595,
#    'level': 18,
#    'hero_damage': 14487,
#    'tower_damage': 6564,
#    'hero_healing': 0,
#    'gold': 2134,
#    'gold_spent': 13670,
#    'scaled_hero_damage': 12651,
#    'scaled_tower_damage': 3803,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5480, 'time': 785, 'level': 1},
#     {'ability': 5482, 'time': 938, 'level': 2},
#     {'ability': 5480, 'time': 1038, 'level': 3},
#     {'ability': 5481, 'time': 1147, 'level': 4},
#     {'ability': 5480, 'time': 1215, 'level': 5},
#     {'ability': 5483, 'time': 1314, 'level': 6},
#     {'ability': 5482, 'time': 1490, 'level': 7},
#     {'ability': 5480, 'time': 1521, 'level': 8},
#     {'ability': 5482, 'time': 1558, 'level': 9},
#     {'ability': 6197, 'time': 1617, 'level': 10},
#     {'ability': 5482, 'time': 1783, 'level': 11},
#     {'ability': 5483, 'time': 1871, 'level': 12},
#     {'ability': 5481, 'time': 1932, 'level': 13},
#     {'ability': 5481, 'time': 2003, 'level': 14},
#     {'ability': 6522, 'time': 2115, 'level': 15},
#     {'ability': 5481, 'time': 2256, 'level': 16}],
#    'hero_name': 'Visage',
#    'item_0_name': 'Boots of Speed',
#    'item_1_name': 'Helm of the Dominator',
#    'item_2_name': 'Crimson Guard',
#    'item_3_name': 'Ring of Aquila',
#    'item_4_name': 'Medallion of Courage',
#    'item_5_name': 'Pipe of Insight',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 254025588,
#    'player_slot': 128,
#    'hero_id': 30,
#    'item_0': 46,
#    'item_1': 0,
#    'item_2': 29,
#    'item_3': 188,
#    'item_4': 0,
#    'item_5': 36,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 6,
#    'leaver_status': 0,
#    'last_hits': 13,
#    'denies': 1,
#    'gold_per_min': 224,
#    'xp_per_min': 214,
#    'level': 10,
#    'hero_damage': 7894,
#    'tower_damage': 0,
#    'hero_healing': 0,
#    'gold': 1215,
#    'gold_spent': 3880,
#    'scaled_hero_damage': 6771,
#    'scaled_tower_damage': 0,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5138, 'time': 914, 'level': 1},
#     {'ability': 5140, 'time': 995, 'level': 2},
#     {'ability': 5140, 'time': 1154, 'level': 3},
#     {'ability': 5138, 'time': 1274, 'level': 4},
#     {'ability': 5140, 'time': 1497, 'level': 5},
#     {'ability': 5141, 'time': 1497, 'level': 6},
#     {'ability': 5138, 'time': 1828, 'level': 7},
#     {'ability': 5140, 'time': 1974, 'level': 8},
#     {'ability': 5138, 'time': 2168, 'level': 9}],
#    'hero_name': 'Witch Doctor',
#    'item_0_name': 'Town Portal Scroll',
#    'item_2_name': 'Boots of Speed',
#    'item_3_name': 'Smoke of Deceit',
#    'item_5_name': 'Magic Wand',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 116249155,
#    'player_slot': 129,
#    'hero_id': 41,
#    'item_0': 172,
#    'item_1': 63,
#    'item_2': 7,
#    'item_3': 11,
#    'item_4': 36,
#    'item_5': 46,
#    'backpack_0': 0,
#    'backpack_1': 182,
#    'backpack_2': 0,
#    'kills': 2,
#    'deaths': 7,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 72,
#    'denies': 2,
#    'gold_per_min': 299,
#    'xp_per_min': 348,
#    'level': 13,
#    'hero_damage': 4655,
#    'tower_damage': 322,
#    'hero_healing': 0,
#    'gold': 855,
#    'gold_spent': 5985,
#    'scaled_hero_damage': 3965,
#    'scaled_tower_damage': 199,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5182, 'time': 851, 'level': 1},
#     {'ability': 5184, 'time': 919, 'level': 2},
#     {'ability': 5691, 'time': 1009, 'level': 3},
#     {'ability': 5182, 'time': 1059, 'level': 4},
#     {'ability': 5182, 'time': 1218, 'level': 5},
#     {'ability': 5185, 'time': 1310, 'level': 6},
#     {'ability': 5182, 'time': 1551, 'level': 7},
#     {'ability': 5184, 'time': 1606, 'level': 8},
#     {'ability': 5184, 'time': 1736, 'level': 9},
#     {'ability': 5184, 'time': 1895, 'level': 10},
#     {'ability': 5960, 'time': 1944, 'level': 11},
#     {'ability': 5185, 'time': 2017, 'level': 12},
#     {'ability': 5691, 'time': 2183, 'level': 13}],
#    'hero_name': 'Faceless Void',
#    'item_0_name': 'Mask of Madness',
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Javelin',
#    'item_3_name': 'Quelling Blade',
#    'item_4_name': 'Magic Wand',
#    'item_5_name': 'Town Portal Scroll',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 86750262,
#    'player_slot': 130,
#    'hero_id': 106,
#    'item_0': 212,
#    'item_1': 63,
#    'item_2': 11,
#    'item_3': 166,
#    'item_4': 36,
#    'item_5': 69,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 5,
#    'deaths': 3,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 130,
#    'denies': 4,
#    'gold_per_min': 416,
#    'xp_per_min': 430,
#    'level': 15,
#    'hero_damage': 14825,
#    'tower_damage': 346,
#    'hero_healing': 0,
#    'gold': 1778,
#    'gold_spent': 8395,
#    'scaled_hero_damage': 10864,
#    'scaled_tower_damage': 266,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5605, 'time': 880, 'level': 1},
#     {'ability': 5603, 'time': 1011, 'level': 2},
#     {'ability': 5605, 'time': 1054, 'level': 3},
#     {'ability': 5603, 'time': 1126, 'level': 4},
#     {'ability': 5605, 'time': 1186, 'level': 5},
#     {'ability': 5606, 'time': 1320, 'level': 6},
#     {'ability': 5605, 'time': 1410, 'level': 7},
#     {'ability': 5604, 'time': 1516, 'level': 8},
#     {'ability': 5604, 'time': 1585, 'level': 9},
#     {'ability': 5603, 'time': 1721, 'level': 10},
#     {'ability': 5604, 'time': 1842, 'level': 11},
#     {'ability': 5604, 'time': 1983, 'level': 12},
#     {'ability': 5603, 'time': 2079, 'level': 13},
#     {'ability': 6009, 'time': 2207, 'level': 14}],
#    'hero_name': 'Ember Spirit',
#    'item_0_name': 'Ring of Aquila',
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Quelling Blade',
#    'item_3_name': 'Maelstrom',
#    'item_4_name': 'Magic Wand',
#    'item_5_name': 'Perseverance',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 66620961,
#    'player_slot': 131,
#    'hero_id': 103,
#    'item_0': 178,
#    'item_1': 23,
#    'item_2': 244,
#    'item_3': 57,
#    'item_4': 34,
#    'item_5': 214,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 1,
#    'deaths': 5,
#    'assists': 14,
#    'leaver_status': 1,
#    'last_hits': 24,
#    'denies': 1,
#    'gold_per_min': 212,
#    'xp_per_min': 237,
#    'level': 10,
#    'hero_damage': 8548,
#    'tower_damage': 0,
#    'hero_healing': 0,
#    'gold': 0,
#    'gold_spent': 5830,
#    'scaled_hero_damage': 6419,
#    'scaled_tower_damage': 0,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5591, 'time': 845, 'level': 1},
#     {'ability': 5589, 'time': 977, 'level': 2},
#     {'ability': 5589, 'time': 1137, 'level': 3},
#     {'ability': 5593, 'time': 1252, 'level': 4},
#     {'ability': 5589, 'time': 1439, 'level': 5},
#     {'ability': 5594, 'time': 1688, 'level': 6},
#     {'ability': 5589, 'time': 1770, 'level': 7},
#     {'ability': 5593, 'time': 1882, 'level': 8},
#     {'ability': 5593, 'time': 2074, 'level': 9},
#     {'ability': 5593, 'time': 2217, 'level': 10}],
#    'hero_name': 'Elder Titan',
#    'item_0_name': 'Soul Ring',
#    'item_1_name': 'Staff of Wizardry',
#    'item_2_name': 'Wind Lace',
#    'item_3_name': 'Void Stone',
#    'item_4_name': 'Magic Stick',
#    'item_5_name': 'Tranquil Boots',
#    'leaver_status_name': 'DISCONNECTED',
#    'leaver_status_description': 'player DC, no abandon'},
#   {'account_id': 86723143,
#    'player_slot': 132,
#    'hero_id': 9,
#    'item_0': 236,
#    'item_1': 212,
#    'item_2': 63,
#    'item_3': 0,
#    'item_4': 36,
#    'item_5': 166,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 6,
#    'deaths': 4,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 141,
#    'denies': 19,
#    'gold_per_min': 474,
#    'xp_per_min': 510,
#    'level': 16,
#    'hero_damage': 13930,
#    'tower_damage': 630,
#    'hero_healing': 0,
#    'gold': 2556,
#    'gold_spent': 8390,
#    'scaled_hero_damage': 10174,
#    'scaled_tower_damage': 428,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5048, 'time': 952, 'level': 1},
#     {'ability': 5050, 'time': 952, 'level': 2},
#     {'ability': 5051, 'time': 1058, 'level': 3},
#     {'ability': 5051, 'time': 1083, 'level': 4},
#     {'ability': 5051, 'time': 1171, 'level': 5},
#     {'ability': 5049, 'time': 1235, 'level': 6},
#     {'ability': 5051, 'time': 1302, 'level': 7},
#     {'ability': 5050, 'time': 1392, 'level': 8},
#     {'ability': 5050, 'time': 1452, 'level': 9},
#     {'ability': 5959, 'time': 1585, 'level': 10},
#     {'ability': 5050, 'time': 1659, 'level': 11},
#     {'ability': 5048, 'time': 1786, 'level': 12},
#     {'ability': 5048, 'time': 1951, 'level': 13},
#     {'ability': 5048, 'time': 2047, 'level': 14},
#     {'ability': 6013, 'time': 2111, 'level': 15}],
#    'hero_name': 'Mirana',
#    'item_0_name': 'Dragon Lance',
#    'item_1_name': 'Ring of Aquila',
#    'item_2_name': 'Power Treads',
#    'item_4_name': 'Magic Wand',
#    'item_5_name': 'Maelstrom',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'}],
#  'radiant_win': True,
#  'duration': 1450,
#  'pre_game_duration': 90,
#  'start_time': 1530376983,
#  'match_id': 3981626536,
#  'match_seq_num': 3454477091,
#  'tower_status_radiant': 1975,
#  'tower_status_dire': 1572,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 47,
#  'cluster': 135,
#  'first_blood_time': 208,
#  'lobby_type': 1,
#  'human_players': 10,
#  'leagueid': 5850,
#  'positive_votes': 145,
#  'negative_votes': 19,
#  'game_mode': 2,
#  'flags': 1,
#  'engine': 1,
#  'radiant_score': 28,
#  'dire_score': 19,
#  'radiant_team_id': 2006913,
#  'radiant_name': 'Vega Squadron',
#  'radiant_logo': 436112540728322951,
#  'radiant_team_complete': 0,
#  'dire_team_id': 3888404,
#  'dire_name': 'MEGA-LADA E-sports',
#  'dire_logo': 929304701411089368,
#  'dire_team_complete': 0,
#  'radiant_captain': 111030315,
#  'dire_captain': 254025588,
#  'picks_bans': [{'is_pick': False, 'hero_id': 12, 'team': 1, 'order': 0},
#   {'is_pick': False, 'hero_id': 21, 'team': 0, 'order': 1},
#   {'is_pick': False, 'hero_id': 62, 'team': 1, 'order': 2},
#   {'is_pick': False, 'hero_id': 52, 'team': 0, 'order': 3},
#   {'is_pick': False, 'hero_id': 91, 'team': 1, 'order': 4},
#   {'is_pick': False, 'hero_id': 89, 'team': 0, 'order': 5},
#   {'is_pick': True, 'hero_id': 9, 'team': 1, 'order': 6},
#   {'is_pick': True, 'hero_id': 3, 'team': 0, 'order': 7},
#   {'is_pick': True, 'hero_id': 4, 'team': 0, 'order': 8},
#   {'is_pick': True, 'hero_id': 41, 'team': 1, 'order': 9},
#   {'is_pick': False, 'hero_id': 69, 'team': 1, 'order': 10},
#   {'is_pick': False, 'hero_id': 16, 'team': 0, 'order': 11},
#   {'is_pick': False, 'hero_id': 46, 'team': 1, 'order': 12},
#   {'is_pick': False, 'hero_id': 75, 'team': 0, 'order': 13},
#   {'is_pick': True, 'hero_id': 20, 'team': 0, 'order': 14},
#   {'is_pick': True, 'hero_id': 103, 'team': 1, 'order': 15},
#   {'is_pick': True, 'hero_id': 49, 'team': 0, 'order': 16},
#   {'is_pick': True, 'hero_id': 106, 'team': 1, 'order': 17},
#   {'is_pick': False, 'hero_id': 68, 'team': 0, 'order': 18},
#   {'is_pick': False, 'hero_id': 61, 'team': 1, 'order': 19},
#   {'is_pick': True, 'hero_id': 30, 'team': 1, 'order': 20},
#   {'is_pick': True, 'hero_id': 92, 'team': 0, 'order': 21}],
#  'lobby_name': 'Practice',
#  'game_mode_name': 'Captains Mode',
#  'cluster_name': 'Europe West'}

# %%
mf['barracks_status_radiant']
dire_assists=0

# %%
dire_assists+= mf['players'][0]['assists']
dire_assists
# Out:
# 4

# %%
dire_assists+= mf['players'][1]['assists']
dire_assists+= mf['players'][2]['assists']
dire_assists+= mf['players'][3]['assists']
dire_assists+= mf['players'][4]['assists']
dire_assists+= mf['players'][5]['assists']

# %%
dire_assists
# Out:
# 54
