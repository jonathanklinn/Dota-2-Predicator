# %%
import dota2api
import numpy as np
import pandas as pd

# %%
api = dota2api.Initialise("B335AEF628EF2F2D2DC5A94BA4A02ED9")

mf=api.get_match_details(3962882047)

# %%
mf
# Out:
# {'players': [{'account_id': 117731777,
#    'player_slot': 0,
#    'hero_id': 75,
#    'item_0': 263,
#    'item_1': 50,
#    'item_2': 254,
#    'item_3': 46,
#    'item_4': 185,
#    'item_5': 43,
#    'backpack_0': 0,
#    'backpack_1': 46,
#    'backpack_2': 0,
#    'kills': 10,
#    'deaths': 4,
#    'assists': 33,
#    'leaver_status': 0,
#    'last_hits': 72,
#    'denies': 6,
#    'gold_per_min': 392,
#    'xp_per_min': 538,
#    'level': 25,
#    'hero_damage': 26608,
#    'tower_damage': 654,
#    'hero_healing': 0,
#    'gold': 4615,
#    'gold_spent': 16115,
#    'scaled_hero_damage': 16582,
#    'scaled_tower_damage': 398,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5377, 'time': 830, 'level': 1},
#     {'ability': 5378, 'time': 889, 'level': 2},
#     {'ability': 5377, 'time': 982, 'level': 3},
#     {'ability': 5379, 'time': 1082, 'level': 4},
#     {'ability': 5377, 'time': 1204, 'level': 5},
#     {'ability': 5380, 'time': 1358, 'level': 6},
#     {'ability': 5377, 'time': 1480, 'level': 7},
#     {'ability': 5379, 'time': 1602, 'level': 8},
#     {'ability': 5379, 'time': 1749, 'level': 9},
#     {'ability': 5379, 'time': 2036, 'level': 10},
#     {'ability': 6016, 'time': 2192, 'level': 11},
#     {'ability': 5380, 'time': 2304, 'level': 12},
#     {'ability': 5378, 'time': 2347, 'level': 13},
#     {'ability': 5378, 'time': 2532, 'level': 14},
#     {'ability': 6008, 'time': 2630, 'level': 15},
#     {'ability': 5378, 'time': 2712, 'level': 16},
#     {'ability': 5380, 'time': 2908, 'level': 17},
#     {'ability': 6879, 'time': 3803, 'level': 18}],
#    'hero_name': 'Silencer',
#    'item_0_name': 'Hurricane Pike',
#    'item_1_name': 'Phase Boots',
#    'item_2_name': 'Glimmer Cape',
#    'item_3_name': 'Town Portal Scroll',
#    'item_4_name': 'Drum of Endurance',
#    'item_5_name': 'Sentry Ward',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 157475523,
#    'player_slot': 1,
#    'hero_id': 22,
#    'item_0': 116,
#    'item_1': 110,
#    'item_2': 48,
#    'item_3': 232,
#    'item_4': 259,
#    'item_5': 108,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 12,
#    'deaths': 5,
#    'assists': 31,
#    'leaver_status': 0,
#    'last_hits': 338,
#    'denies': 4,
#    'gold_per_min': 543,
#    'xp_per_min': 651,
#    'level': 25,
#    'hero_damage': 68528,
#    'tower_damage': 109,
#    'hero_healing': 0,
#    'gold': 3879,
#    'gold_spent': 26435,
#    'scaled_hero_damage': 28909,
#    'scaled_tower_damage': 51,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5111, 'time': 709, 'level': 1},
#     {'ability': 5112, 'time': 908, 'level': 2},
#     {'ability': 5111, 'time': 978, 'level': 3},
#     {'ability': 5110, 'time': 1052, 'level': 4},
#     {'ability': 5110, 'time': 1171, 'level': 5},
#     {'ability': 5113, 'time': 1270, 'level': 6},
#     {'ability': 5111, 'time': 1344, 'level': 7},
#     {'ability': 5111, 'time': 1497, 'level': 8},
#     {'ability': 5110, 'time': 1581, 'level': 9},
#     {'ability': 5987, 'time': 1694, 'level': 10},
#     {'ability': 5110, 'time': 1778, 'level': 11},
#     {'ability': 5113, 'time': 1812, 'level': 12},
#     {'ability': 5112, 'time': 1904, 'level': 13},
#     {'ability': 5112, 'time': 1967, 'level': 14},
#     {'ability': 6141, 'time': 2168, 'level': 15},
#     {'ability': 5112, 'time': 2298, 'level': 16},
#     {'ability': 5113, 'time': 2575, 'level': 17},
#     {'ability': 6518, 'time': 2741, 'level': 18},
#     {'ability': 6501, 'time': 3286, 'level': 19}],
#    'hero_name': 'Zeus',
#    'item_0_name': 'Black King Bar',
#    'item_1_name': 'Refresher Orb',
#    'item_2_name': 'Boots of Travel',
#    'item_3_name': 'Aether Lens',
#    'item_5_name': "Aghanim's Scepter",
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 168028715,
#    'player_slot': 2,
#    'hero_id': 41,
#    'item_0': 152,
#    'item_1': 172,
#    'item_2': 116,
#    'item_3': 158,
#    'item_4': 0,
#    'item_5': 63,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 10,
#    'deaths': 9,
#    'assists': 22,
#    'leaver_status': 0,
#    'last_hits': 271,
#    'denies': 17,
#    'gold_per_min': 489,
#    'xp_per_min': 525,
#    'level': 25,
#    'hero_damage': 23999,
#    'tower_damage': 2455,
#    'hero_healing': 0,
#    'gold': 6294,
#    'gold_spent': 18785,
#    'scaled_hero_damage': 13500,
#    'scaled_tower_damage': 1521,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5182, 'time': 828, 'level': 1},
#     {'ability': 5184, 'time': 890, 'level': 2},
#     {'ability': 5691, 'time': 987, 'level': 3},
#     {'ability': 5182, 'time': 1067, 'level': 4},
#     {'ability': 5184, 'time': 1192, 'level': 5},
#     {'ability': 5185, 'time': 1265, 'level': 6},
#     {'ability': 5184, 'time': 1373, 'level': 7},
#     {'ability': 5184, 'time': 1567, 'level': 8},
#     {'ability': 5182, 'time': 1674, 'level': 9},
#     {'ability': 5182, 'time': 1811, 'level': 10},
#     {'ability': 5960, 'time': 1888, 'level': 11},
#     {'ability': 5185, 'time': 1987, 'level': 12},
#     {'ability': 5691, 'time': 2097, 'level': 13},
#     {'ability': 5691, 'time': 2220, 'level': 14},
#     {'ability': 6807, 'time': 2423, 'level': 15},
#     {'ability': 5691, 'time': 2557, 'level': 16},
#     {'ability': 5185, 'time': 2745, 'level': 17},
#     {'ability': 6128, 'time': 3084, 'level': 18},
#     {'ability': 6651, 'time': 3901, 'level': 19}],
#    'hero_name': 'Faceless Void',
#    'item_0_name': 'Shadow Blade',
#    'item_1_name': 'Mask of Madness',
#    'item_2_name': 'Black King Bar',
#    'item_3_name': 'Mjollnir',
#    'item_5_name': 'Power Treads',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 124936122,
#    'player_slot': 3,
#    'hero_id': 25,
#    'item_0': 50,
#    'item_1': 100,
#    'item_2': 149,
#    'item_3': 152,
#    'item_4': 116,
#    'item_5': 123,
#    'backpack_0': 46,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 12,
#    'deaths': 8,
#    'assists': 20,
#    'leaver_status': 0,
#    'last_hits': 347,
#    'denies': 13,
#    'gold_per_min': 540,
#    'xp_per_min': 645,
#    'level': 25,
#    'hero_damage': 37363,
#    'tower_damage': 6065,
#    'hero_healing': 500,
#    'gold': 4856,
#    'gold_spent': 20855,
#    'scaled_hero_damage': 20610,
#    'scaled_tower_damage': 3873,
#    'scaled_hero_healing': 264,
#    'ability_upgrades': [{'ability': 5040, 'time': 825, 'level': 1},
#     {'ability': 5042, 'time': 851, 'level': 2},
#     {'ability': 5040, 'time': 896, 'level': 3},
#     {'ability': 5041, 'time': 948, 'level': 4},
#     {'ability': 5040, 'time': 1029, 'level': 5},
#     {'ability': 5043, 'time': 1119, 'level': 6},
#     {'ability': 5040, 'time': 1185, 'level': 7},
#     {'ability': 5041, 'time': 1303, 'level': 8},
#     {'ability': 5041, 'time': 1448, 'level': 9},
#     {'ability': 6197, 'time': 1555, 'level': 10},
#     {'ability': 5041, 'time': 1618, 'level': 11},
#     {'ability': 5043, 'time': 1749, 'level': 12},
#     {'ability': 5042, 'time': 1809, 'level': 13},
#     {'ability': 5042, 'time': 1929, 'level': 14},
#     {'ability': 6195, 'time': 2050, 'level': 15},
#     {'ability': 5042, 'time': 2112, 'level': 16},
#     {'ability': 5043, 'time': 2385, 'level': 17},
#     {'ability': 6313, 'time': 2628, 'level': 18},
#     {'ability': 6186, 'time': 3357, 'level': 19}],
#    'hero_name': 'Lina',
#    'item_0_name': 'Phase Boots',
#    'item_1_name': "Eul's Scepter of Divinity",
#    'item_2_name': 'Crystalys',
#    'item_3_name': 'Shadow Blade',
#    'item_4_name': 'Black King Bar',
#    'item_5_name': "Linken's Sphere",
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 138543123,
#    'player_slot': 4,
#    'hero_id': 60,
#    'item_0': 90,
#    'item_1': 50,
#    'item_2': 267,
#    'item_3': 36,
#    'item_4': 127,
#    'item_5': 30,
#    'backpack_0': 46,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 4,
#    'deaths': 10,
#    'assists': 31,
#    'leaver_status': 0,
#    'last_hits': 105,
#    'denies': 9,
#    'gold_per_min': 310,
#    'xp_per_min': 525,
#    'level': 25,
#    'hero_damage': 15719,
#    'tower_damage': 871,
#    'hero_healing': 635,
#    'gold': 3193,
#    'gold_spent': 12595,
#    'scaled_hero_damage': 7613,
#    'scaled_tower_damage': 533,
#    'scaled_hero_healing': 286,
#    'ability_upgrades': [{'ability': 5275, 'time': 760, 'level': 1},
#     {'ability': 5277, 'time': 908, 'level': 2},
#     {'ability': 5275, 'time': 1067, 'level': 3},
#     {'ability': 5277, 'time': 1255, 'level': 4},
#     {'ability': 5275, 'time': 1403, 'level': 5},
#     {'ability': 5278, 'time': 1489, 'level': 6},
#     {'ability': 5275, 'time': 1579, 'level': 7},
#     {'ability': 5276, 'time': 1725, 'level': 8},
#     {'ability': 5277, 'time': 1884, 'level': 9},
#     {'ability': 5277, 'time': 2034, 'level': 10},
#     {'ability': 5959, 'time': 2056, 'level': 11},
#     {'ability': 5278, 'time': 2264, 'level': 12},
#     {'ability': 5276, 'time': 2347, 'level': 13},
#     {'ability': 5276, 'time': 2528, 'level': 14},
#     {'ability': 6145, 'time': 2605, 'level': 15},
#     {'ability': 5276, 'time': 2627, 'level': 16},
#     {'ability': 5278, 'time': 2816, 'level': 17},
#     {'ability': 6249, 'time': 3123, 'level': 18}],
#    'hero_name': 'Night Stalker',
#    'item_0_name': 'Pipe of Insight',
#    'item_1_name': 'Phase Boots',
#    'item_3_name': 'Magic Wand',
#    'item_4_name': 'Blade Mail',
#    'item_5_name': 'Gem of True Sight',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 849035415,
#    'player_slot': 128,
#    'hero_id': 87,
#    'item_0': 218,
#    'item_1': 188,
#    'item_2': 244,
#    'item_3': 36,
#    'item_4': 254,
#    'item_5': 214,
#    'backpack_0': 0,
#    'backpack_1': 46,
#    'backpack_2': 0,
#    'kills': 3,
#    'deaths': 13,
#    'assists': 13,
#    'leaver_status': 0,
#    'last_hits': 19,
#    'denies': 2,
#    'gold_per_min': 259,
#    'xp_per_min': 353,
#    'level': 20,
#    'hero_damage': 9601,
#    'tower_damage': 0,
#    'hero_healing': 400,
#    'gold': 358,
#    'gold_spent': 12310,
#    'scaled_hero_damage': 7618,
#    'scaled_tower_damage': 0,
#    'scaled_hero_healing': 328,
#    'ability_upgrades': [{'ability': 5458, 'time': 810, 'level': 1},
#     {'ability': 5460, 'time': 940, 'level': 2},
#     {'ability': 5459, 'time': 1094, 'level': 3},
#     {'ability': 5459, 'time': 1263, 'level': 4},
#     {'ability': 5459, 'time': 1390, 'level': 5},
#     {'ability': 5461, 'time': 1436, 'level': 6},
#     {'ability': 5459, 'time': 1465, 'level': 7},
#     {'ability': 5460, 'time': 1759, 'level': 8},
#     {'ability': 5460, 'time': 2045, 'level': 9},
#     {'ability': 5959, 'time': 2163, 'level': 10},
#     {'ability': 5460, 'time': 2228, 'level': 11},
#     {'ability': 5461, 'time': 2425, 'level': 12},
#     {'ability': 5458, 'time': 2742, 'level': 13},
#     {'ability': 5458, 'time': 3013, 'level': 14},
#     {'ability': 6056, 'time': 3068, 'level': 15},
#     {'ability': 5458, 'time': 3160, 'level': 16},
#     {'ability': 5461, 'time': 3336, 'level': 17},
#     {'ability': 6026, 'time': 3502, 'level': 18}],
#    'hero_name': 'Disruptor',
#    'item_0_name': 'Observer and Sentry Wards',
#    'item_1_name': 'Smoke of Deceit',
#    'item_2_name': 'Wind Lace',
#    'item_3_name': 'Magic Wand',
#    'item_4_name': 'Glimmer Cape',
#    'item_5_name': 'Tranquil Boots',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 119576842,
#    'player_slot': 129,
#    'hero_id': 16,
#    'item_0': 0,
#    'item_1': 1,
#    'item_2': 102,
#    'item_3': 214,
#    'item_4': 256,
#    'item_5': 34,
#    'backpack_0': 40,
#    'backpack_1': 0,
#    'backpack_2': 38,
#    'kills': 3,
#    'deaths': 12,
#    'assists': 16,
#    'leaver_status': 1,
#    'last_hits': 63,
#    'denies': 2,
#    'gold_per_min': 264,
#    'xp_per_min': 331,
#    'level': 20,
#    'hero_damage': 11344,
#    'tower_damage': 0,
#    'hero_healing': 0,
#    'gold': 171,
#    'gold_spent': 12285,
#    'scaled_hero_damage': 7115,
#    'scaled_tower_damage': 0,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5102, 'time': 714, 'level': 1},
#     {'ability': 5104, 'time': 916, 'level': 2},
#     {'ability': 5102, 'time': 1004, 'level': 3},
#     {'ability': 5103, 'time': 1219, 'level': 4},
#     {'ability': 5102, 'time': 1268, 'level': 5},
#     {'ability': 5103, 'time': 1431, 'level': 6},
#     {'ability': 5102, 'time': 1471, 'level': 7},
#     {'ability': 5105, 'time': 1738, 'level': 8},
#     {'ability': 5103, 'time': 1798, 'level': 9},
#     {'ability': 5959, 'time': 1986, 'level': 10},
#     {'ability': 5103, 'time': 2026, 'level': 11},
#     {'ability': 5105, 'time': 2223, 'level': 12},
#     {'ability': 5104, 'time': 2416, 'level': 13},
#     {'ability': 5104, 'time': 2930, 'level': 14},
#     {'ability': 6409, 'time': 3070, 'level': 15},
#     {'ability': 5104, 'time': 3349, 'level': 16},
#     {'ability': 5105, 'time': 3451, 'level': 17},
#     {'ability': 6004, 'time': 3793, 'level': 18}],
#    'hero_name': 'Sand King',
#    'item_1_name': 'Blink Dagger',
#    'item_2_name': 'Force Staff',
#    'item_3_name': 'Tranquil Boots',
#    'item_5_name': 'Magic Stick',
#    'leaver_status_name': 'DISCONNECTED',
#    'leaver_status_description': 'player DC, no abandon'},
#   {'account_id': 90882159,
#    'player_slot': 130,
#    'hero_id': 43,
#    'item_0': 256,
#    'item_1': 100,
#    'item_2': 131,
#    'item_3': 116,
#    'item_4': 119,
#    'item_5': 110,
#    'backpack_0': 0,
#    'backpack_1': 50,
#    'backpack_2': 0,
#    'kills': 10,
#    'deaths': 5,
#    'assists': 9,
#    'leaver_status': 1,
#    'last_hits': 370,
#    'denies': 13,
#    'gold_per_min': 558,
#    'xp_per_min': 663,
#    'level': 25,
#    'hero_damage': 32646,
#    'tower_damage': 1523,
#    'hero_healing': 0,
#    'gold': 798,
#    'gold_spent': 25610,
#    'scaled_hero_damage': 16413,
#    'scaled_tower_damage': 892,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5090, 'time': 817, 'level': 1},
#     {'ability': 5685, 'time': 846, 'level': 2},
#     {'ability': 5090, 'time': 906, 'level': 3},
#     {'ability': 5685, 'time': 971, 'level': 4},
#     {'ability': 5090, 'time': 1060, 'level': 5},
#     {'ability': 5093, 'time': 1145, 'level': 6},
#     {'ability': 5685, 'time': 1218, 'level': 7},
#     {'ability': 5685, 'time': 1316, 'level': 8},
#     {'ability': 5090, 'time': 1336, 'level': 9},
#     {'ability': 5940, 'time': 1475, 'level': 10},
#     {'ability': 5091, 'time': 1577, 'level': 11},
#     {'ability': 5093, 'time': 1721, 'level': 12},
#     {'ability': 5091, 'time': 1815, 'level': 13},
#     {'ability': 5091, 'time': 1887, 'level': 14},
#     {'ability': 6056, 'time': 1999, 'level': 15},
#     {'ability': 5091, 'time': 2139, 'level': 16},
#     {'ability': 5093, 'time': 2483, 'level': 17},
#     {'ability': 6235, 'time': 2819, 'level': 18},
#     {'ability': 6805, 'time': 3246, 'level': 19}],
#    'hero_name': 'Death Prophet',
#    'item_1_name': "Eul's Scepter of Divinity",
#    'item_2_name': 'Hood of Defiance',
#    'item_3_name': 'Black King Bar',
#    'item_4_name': "Shiva's Guard",
#    'item_5_name': 'Refresher Orb',
#    'leaver_status_name': 'DISCONNECTED',
#    'leaver_status_description': 'player DC, no abandon'},
#   {'account_id': 148215639,
#    'player_slot': 131,
#    'hero_id': 52,
#    'item_0': 1,
#    'item_1': 96,
#    'item_2': 116,
#    'item_3': 100,
#    'item_4': 48,
#    'item_5': 121,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 16,
#    'deaths': 7,
#    'assists': 13,
#    'leaver_status': 0,
#    'last_hits': 413,
#    'denies': 14,
#    'gold_per_min': 607,
#    'xp_per_min': 643,
#    'level': 25,
#    'hero_damage': 32714,
#    'tower_damage': 2052,
#    'hero_healing': 0,
#    'gold': 2405,
#    'gold_spent': 24295,
#    'scaled_hero_damage': 21224,
#    'scaled_tower_damage': 1331,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5241, 'time': 738, 'level': 1},
#     {'ability': 5243, 'time': 886, 'level': 2},
#     {'ability': 5243, 'time': 978, 'level': 3},
#     {'ability': 5241, 'time': 1031, 'level': 4},
#     {'ability': 5243, 'time': 1116, 'level': 5},
#     {'ability': 5244, 'time': 1197, 'level': 6},
#     {'ability': 5243, 'time': 1262, 'level': 7},
#     {'ability': 5242, 'time': 1327, 'level': 8},
#     {'ability': 5242, 'time': 1446, 'level': 9},
#     {'ability': 5242, 'time': 1533, 'level': 10},
#     {'ability': 5242, 'time': 1658, 'level': 11},
#     {'ability': 5241, 'time': 1793, 'level': 12},
#     {'ability': 5241, 'time': 1901, 'level': 13},
#     {'ability': 5932, 'time': 2026, 'level': 14},
#     {'ability': 6145, 'time': 2137, 'level': 15},
#     {'ability': 5244, 'time': 2317, 'level': 16},
#     {'ability': 5244, 'time': 2567, 'level': 17},
#     {'ability': 6672, 'time': 2913, 'level': 18},
#     {'ability': 6063, 'time': 3325, 'level': 19}],
#    'hero_name': 'Leshrac',
#    'item_0_name': 'Blink Dagger',
#    'item_1_name': 'Scythe of Vyse',
#    'item_2_name': 'Black King Bar',
#    'item_3_name': "Eul's Scepter of Divinity",
#    'item_4_name': 'Boots of Travel',
#    'item_5_name': 'Bloodstone',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 111189717,
#    'player_slot': 132,
#    'hero_id': 69,
#    'item_0': 116,
#    'item_1': 1,
#    'item_2': 36,
#    'item_3': 90,
#    'item_4': 50,
#    'item_5': 46,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 3,
#    'deaths': 13,
#    'assists': 13,
#    'leaver_status': 0,
#    'last_hits': 149,
#    'denies': 11,
#    'gold_per_min': 394,
#    'xp_per_min': 336,
#    'level': 20,
#    'hero_damage': 14811,
#    'tower_damage': 94,
#    'hero_healing': 0,
#    'gold': 1869,
#    'gold_spent': 15525,
#    'scaled_hero_damage': 10584,
#    'scaled_tower_damage': 75,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5339, 'time': 832, 'level': 1},
#     {'ability': 5341, 'time': 890, 'level': 2},
#     {'ability': 5341, 'time': 1063, 'level': 3},
#     {'ability': 5340, 'time': 1102, 'level': 4},
#     {'ability': 5341, 'time': 1220, 'level': 5},
#     {'ability': 5342, 'time': 1357, 'level': 6},
#     {'ability': 5341, 'time': 1420, 'level': 7},
#     {'ability': 5340, 'time': 1541, 'level': 8},
#     {'ability': 5340, 'time': 1705, 'level': 9},
#     {'ability': 5339, 'time': 1771, 'level': 10},
#     {'ability': 7123, 'time': 1887, 'level': 11},
#     {'ability': 5342, 'time': 1960, 'level': 12},
#     {'ability': 5339, 'time': 2046, 'level': 13},
#     {'ability': 5340, 'time': 2223, 'level': 14},
#     {'ability': 6369, 'time': 2324, 'level': 15},
#     {'ability': 5339, 'time': 2551, 'level': 16},
#     {'ability': 5342, 'time': 3031, 'level': 17},
#     {'ability': 6371, 'time': 3784, 'level': 18}],
#    'hero_name': 'Doom',
#    'item_0_name': 'Black King Bar',
#    'item_1_name': 'Blink Dagger',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Pipe of Insight',
#    'item_4_name': 'Phase Boots',
#    'item_5_name': 'Town Portal Scroll',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'}],
#  'radiant_win': True,
#  'duration': 3110,
#  'pre_game_duration': 90,
#  'start_time': 1529481203,
#  'match_id': 3962882047,
#  'match_seq_num': 3438129084,
#  'tower_status_radiant': 1846,
#  'tower_status_dire': 1792,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 48,
#  'cluster': 223,
#  'first_blood_time': 138,
#  'lobby_type': 1,
#  'human_players': 10,
#  'leagueid': 9870,
#  'positive_votes': 335,
#  'negative_votes': 48,
#  'game_mode': 2,
#  'flags': 1,
#  'engine': 1,
#  'radiant_score': 49,
#  'dire_score': 35,
#  'radiant_team_id': 5066616,
#  'radiant_name': 'Team Serenity',
#  'radiant_logo': 869616562083341135,
#  'radiant_team_complete': 0,
#  'dire_team_id': 3331948,
#  'dire_name': 'LGD.Forever Young',
#  'dire_logo': 92725562078077112,
#  'dire_team_complete': 0,
#  'radiant_captain': 117731777,
#  'dire_captain': 849035415,
#  'picks_bans': [{'is_pick': False, 'hero_id': 99, 'team': 0, 'order': 0},
#   {'is_pick': False, 'hero_id': 21, 'team': 1, 'order': 1},
#   {'is_pick': False, 'hero_id': 38, 'team': 0, 'order': 2},
#   {'is_pick': False, 'hero_id': 12, 'team': 1, 'order': 3},
#   {'is_pick': False, 'hero_id': 77, 'team': 0, 'order': 4},
#   {'is_pick': False, 'hero_id': 9, 'team': 1, 'order': 5},
#   {'is_pick': True, 'hero_id': 60, 'team': 0, 'order': 6},
#   {'is_pick': True, 'hero_id': 87, 'team': 1, 'order': 7},
#   {'is_pick': True, 'hero_id': 43, 'team': 1, 'order': 8},
#   {'is_pick': True, 'hero_id': 25, 'team': 0, 'order': 9},
#   {'is_pick': False, 'hero_id': 51, 'team': 0, 'order': 10},
#   {'is_pick': False, 'hero_id': 4, 'team': 1, 'order': 11},
#   {'is_pick': False, 'hero_id': 56, 'team': 0, 'order': 12},
#   {'is_pick': False, 'hero_id': 54, 'team': 1, 'order': 13},
#   {'is_pick': True, 'hero_id': 52, 'team': 1, 'order': 14},
#   {'is_pick': True, 'hero_id': 75, 'team': 0, 'order': 15},
#   {'is_pick': True, 'hero_id': 69, 'team': 1, 'order': 16},
#   {'is_pick': True, 'hero_id': 41, 'team': 0, 'order': 17},
#   {'is_pick': False, 'hero_id': 17, 'team': 1, 'order': 18},
#   {'is_pick': False, 'hero_id': 89, 'team': 0, 'order': 19},
#   {'is_pick': True, 'hero_id': 22, 'team': 0, 'order': 20},
#   {'is_pick': True, 'hero_id': 16, 'team': 1, 'order': 21}],
#  'lobby_name': 'Practice',
#  'game_mode_name': 'Captains Mode',
#  'cluster_name': 'China'}

# %%
mf['barracks_status_radiant']
dire_assists=0

mf['']

# %%
dire_assists+= mf['players'][0]['assists']
dire_assists
# Out:
# 104

# %%
dire_assists+= mf['players'][1]['assists']
dire_assists+= mf['players'][2]['assists']
dire_assists+= mf['players'][3]['assists']
dire_assists+= mf['players'][4]['assists']
dire_assists+= mf['players'][5]['assists']

# %%
dire_assists
# Out:
# 198
