# %%
import dota2api
import pprint
import pandas as pd
import numpy as np

api= dota2api.Initialise("B335AEF628EF2F2D2DC5A94BA4A02ED9")

matches_data= pd.read_csv("data/match_ids.csv")


pd.set_option('display.expand_frame_repr', False)


matches_data['Radiant'] = ''
matches_data['Dire'] = ''

matches_data['radiant_assists'] = 0
matches_data['radiant_barracks'] = 0
matches_data['radiant_denies'] = 0
matches_data['radiant_gpm'] = 0
matches_data['radiant_healing'] = 0
matches_data['radiant_hero_damage'] = 0
matches_data['radiant_kills'] = 0
matches_data['radiant_last_hits'] = 0
matches_data['radiant_total_levels'] = 0
matches_data['radiant_tower_damage'] = 0
matches_data['radiant_tower_status'] = 0
matches_data['radiant_xpm'] = 0

matches_data['dire_assists'] = 0
matches_data['dire_barracks'] = 0
matches_data['dire_denies'] = 0
matches_data['dire_gpm'] = 0
matches_data['dire_healing'] = 0
matches_data['dire_hero_damage'] = 0
matches_data['dire_kills'] = 0
matches_data['dire_last_hits'] = 0
matches_data['dire_total_levels'] = 0
matches_data['dire_tower_damage'] = 0
matches_data['dire_tower_status'] = 0
matches_data['dire_xpm'] = 0

matches_data['first_blood'] = 0
matches_data['match_duration'] = 0
matches_data['radiant_winner'] = 0

for i in range(0, len(matches_data)): 
    # MATCH
    first_blood          = 0
    match_duration       = 0
    match_winner         = 0

# RADIANT
    radiant_assists      = 0
    radiant_denies       = 0
    radiant_gpm          = 0
    radiant_healing      = 0
    radiant_hero_damage  = 0
    radiant_kills        = 0
    radiant_last_hits    = 0
    radiant_name         = ""
    radiant_total_levels = 0
    radiant_tower_damage = 0
    radiant_xpm          = 0 #26905 xp for 25
    radiant_barracks     = 0

# DIRE
    dire_assists         = 0
    dire_denies          = 0
    dire_gpm             = 0
    dire_healing         = 0
    dire_hero_damage     = 0
    dire_kills           = 0
    dire_last_hits       = 0
    dire_name            = ""
    dire_total_levels    = 0
    dire_tower_damage    = 0
    dire_xpm             = 0
    dire_barracks        = 0

    current_match = matches_data['match_id'][i]
    print(current_match)
    try:
        match = api.get_match_details(match_id = current_match)
        for x in range(0, 5):
            radiant_assists      += match['players'][x]['assists']
            radiant_denies       += match['players'][x]['denies']
            radiant_gpm          += match['players'][x]['gold_per_min']
            radiant_healing      += match['players'][x]['hero_healing']
            radiant_hero_damage  += match['players'][x]['hero_damage']
            radiant_kills        += match['players'][x]['kills']
            radiant_last_hits    += match['players'][x]['last_hits']
            radiant_total_levels += match['players'][x]['level']
            radiant_tower_damage += match['players'][x]['tower_damage']
            radiant_xpm          += match['players'][x]['xp_per_min']

            radiant_barracks = match['barracks_status_radiant']
            radiant_name = match['radiant_name']
            radiant_tower_status = match['tower_status_radiant']

        matches_data.loc[i, 'radiant_assists'] = radiant_assists
        matches_data.loc[i, 'radiant_barracks'] = radiant_barracks
        matches_data.loc[i, 'radiant_denies'] = radiant_denies
        matches_data.loc[i, 'radiant_gpm'] = radiant_gpm
        matches_data.loc[i, 'radiant_healing'] = radiant_healing
        matches_data.loc[i, 'radiant_hero_damage'] = radiant_hero_damage
        matches_data.loc[i, 'radiant_kills'] = radiant_kills
        matches_data.loc[i, 'radiant_last_hits'] = radiant_last_hits
        matches_data.loc[i, 'Radiant'] = radiant_name
        matches_data.loc[i, 'radiant_total_levels'] = radiant_total_levels
        matches_data.loc[i, 'radiant_tower_status'] = radiant_tower_status
        matches_data.loc[i, 'radiant_tower_damage'] = radiant_tower_damage
        matches_data.loc[i, 'radiant_xpm'] = radiant_xpm

        for x in range(5, 10):
            dire_assists      += match['players'][x]['assists']
            dire_denies       += match['players'][x]['denies']
            dire_gpm          += match['players'][x]['gold_per_min']
            dire_healing      += match['players'][x]['hero_healing']
            dire_hero_damage  += match['players'][x]['hero_damage']
            dire_kills        += match['players'][x]['kills']
            dire_last_hits    += match['players'][x]['last_hits']
            dire_total_levels += match['players'][x]['level']
            dire_tower_damage += match['players'][x]['tower_damage']
            dire_xpm          += match['players'][x]['xp_per_min']

            dire_barracks = match['barracks_status_dire']
            dire_name = match['dire_name']
            dire_tower_status = match['tower_status_dire']

        matches_data.loc[i, 'dire_assists'] = dire_assists
        matches_data.loc[i, 'dire_barracks'] = dire_barracks
        matches_data.loc[i, 'dire_denies'] = dire_denies
        matches_data.loc[i, 'dire_gpm'] = dire_gpm
        matches_data.loc[i, 'dire_healing'] = dire_healing
        matches_data.loc[i, 'dire_hero_damage'] = dire_hero_damage
        matches_data.loc[i, 'dire_kills'] = dire_kills
        matches_data.loc[i, 'dire_last_hits'] = dire_last_hits
        matches_data.loc[i, 'Dire'] = dire_name
        matches_data.loc[i, 'dire_total_levels'] = dire_total_levels
        matches_data.loc[i, 'dire_tower_damage'] = dire_tower_damage
        matches_data.loc[i, 'dire_tower_status'] = dire_tower_status
        matches_data.loc[i, 'dire_xpm'] = dire_xpm

        first_blood= match['first_blood_time']
        match_duration       = match['duration']
        
        if (match['radiant_win'] == True):
            match_winner = 1
        else:
            match_winner = 0

        matches_data.loc[i, 'first_blood'] = first_blood
        matches_data.loc[i, 'match_duration'] = match_duration
        matches_data.loc[i, 'radiant_winner'] = match_winner
    except:
        print("Could not find data for ",  current_match)

pprint.pprint(matches_data.head(10))
matches_data.to_csv("data/full_data.csv", index=False)
# Out:
# 4061660411
# 4061662358
# 4061671194
# 4061694810
# 4061721528
# 4061742840
# 4061745637
# 4061766981
# 4061802430
# 4061804100
# 4061815647
# 4061848287
# 4061858332
# 4061867364
# 4061880066
# 4061903681
# 4061921764
# 4061922574
# 4061924528
# 4061952570
# 4061971770
# 4061977166
# 4061984521
# 4062010988
# 4062016236
# 4062017242
# 4062034566
# 4062045592
# 4062047269
# 4062061780
# 4062062147
# 4062098361
# 4062098446
# 4062099038
# 4062103539
# 4062142402
# 4062142571
# 4062143387
# 4062151757
# 4062183675
# 4063131353
# 4063131371
# 4063131418
# 4063131437
# 4063202564
# 4063220819
# 4063222284
# 4063225719
# 4063266100
# 4063286002
# 4063289036
# 4063299885
# 4063350513
# 4063359785
# 4063369023
# 4063378608
# 4063402142
# 4063413580
# 4063430773
# 4063439681
# 4063465788
# 4063477071
# 4063481435
# 4063490254
# 4063518923
# 4063521022
# 4063527110
# 4063532336
# 4063558826
# 4063563567
# 4063571098
# 4063572817
# 4063600107
# 4063601628
# 4063611898
# 4063619584
# 4063643412
# 4063646692
# 4063653342
# 4063667075
# 4064706272
# 4064706284
# 4064708096
# 4064721264
# 4064786062
# 4064786780
# 4064796732
# 4064812973
# 4064851344
# 4064854156
# 4064867263
# 4064872015
# 4064938488
# 4064939549
# 4064949771
# 4064970428
# 4064993264
# 4064996401
# 4065016209
# 4065017593
# 4065042825
# 4065077879
# 4065083072
# 4065084843
# 4065095713
# 4065124105
# 4065128649
# 4065129977
# 4065140946
# 4065164937
# 4065175507
# 4065178894
# 4065192690
# 4065211201
# 4065211218
# 4065229720
# 4065251250
# 4065260154
# 4065268827
# 4065281130
# 4066499119
# 4066499349
# 4066505440
# 4066517897
# 4066597494
# 4066598139
# 4066608591
# 4066615144
# 4066666471
# 4066670110
# 4066688247
# 4066704198
# 4066751467
# 4066759760
# 4066760701
# 4066775838
# 4066822873
# 4066823822
# 4066831697
# 4066838505
# 4066891298
# 4066891674
# 4066909869
# 4066926568
# 4066988194
# 4066995932
# 4067035268
# 4067049273
# 4070356125
# 4070423361
# 4070500759
# 4070556816
# 4070612749
# 4070674710
# 4070746269
# 4070838238
# 4072252473
# 4072354014
# 4072441405
# 4072509593
# 4072586507
# 4072635180
# 4072699199
# 4072772695
# 4074178274
# 4074255285
# 4074356696
# 4074440208
# 4074486307
# 4074591870
# 4074639753
# 4074694505
# 4074748928
# 4074821374
# 4076043995
# 4076114893
# 4076188379
# 4076257095
# 4076314248
#      match_id        Radiant             Dire  radiant_assists  radiant_barracks  radiant_denies  radiant_gpm  radiant_healing  radiant_hero_damage  radiant_kills       ...        dire_hero_damage  dire_kills  dire_last_hits  dire_total_levels  dire_tower_damage  dire_tower_status  dire_xpm  first_blood  match_duration  radiant_winner
# 0  4061660411         Fnatic      Team Liquid               80                 0              54         2097            22103               134426             41       ...                  158912          42            1142                123              20645               1952      2932           15            3031               0
# 1  4061662358  Evil Geniuses      VGJ Thunder              117                63              33         2878             8934               171483             49       ...                  117902          37            1071                118               4730                  0      2778          111            3035               1
# 2  4061671194             OG          PSG.LGD               34                15              33         1417             1565                55736             13       ...                   73373          41             722                 96              11241               1982      2843           98            1735               0
# 3  4061694810        Mineski  Invictus Gaming               41                 0              46         1975             2982                70218             17       ...                   84822          23            1046                106              22836               1840      2429          435            2528               0
# 4  4061721528             OG          PSG.LGD              103                63              33         2346             4558               145076             41       ...                  100679          30            1256                117               7894                  0      2732            0            2810               1
# 5  4061742840         Fnatic      Team Liquid               91                63              60         2362             7737                74234             39       ...                   42112           1             556                 66               3320               1796      1317           51            1905               1
# 6  4061745637  Evil Geniuses      VGJ Thunder               79                63              35         2241             1977                78556             41       ...                   38276          14             426                 67               1404               1792      1772          102            1505               1
# 7  4061766981        Mineski  Invictus Gaming               77                63              24         2508             3850                90748             25       ...                   71207          23            1032                103               6922                512      2492          109            2308               1
# 8  4061802430   OpTic Gaming       Virtus.pro               56                 3              70         2022             7139                76460             29       ...                  106950          42            1001                121              12062               1828      3102          135            2660               0
# 9  4061804100      VGJ Storm      Vici Gaming               36                63              51         2329             4064                59869             20       ...                   40831           7             701                 77               4184               1536      1742          196            1956               1
#
# [10 rows x 30 columns]

# %%
# Out:
# {'players': [{'account_id': 86726887,
#    'player_slot': 0,
#    'hero_id': 119,
#    'item_0': 29,
#    'item_1': 36,
#    'item_2': 100,
#    'item_3': 0,
#    'item_4': 46,
#    'item_5': 267,
#    'backpack_0': 40,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 5,
#    'deaths': 2,
#    'assists': 7,
#    'leaver_status': 0,
#    'last_hits': 52,
#    'denies': 2,
#    'gold_per_min': 339,
#    'xp_per_min': 332,
#    'level': 15,
#    'hero_damage': 9026,
#    'tower_damage': 396,
#    'hero_healing': 1247,
#    'gold': 1813,
#    'gold_spent': 9930,
#    'scaled_hero_damage': 5975,
#    'scaled_tower_damage': 242,
#    'scaled_hero_healing': 709,
#    'ability_upgrades': [{'ability': 6341, 'time': 1069, 'level': 1},
#     {'ability': 6339, 'time': 1102, 'level': 2},
#     {'ability': 6341, 'time': 1247, 'level': 3},
#     {'ability': 6342, 'time': 1385, 'level': 4},
#     {'ability': 6341, 'time': 1571, 'level': 5},
#     {'ability': 8340, 'time': 1616, 'level': 6},
#     {'ability': 6341, 'time': 1673, 'level': 7},
#     {'ability': 6339, 'time': 1855, 'level': 8},
#     {'ability': 6339, 'time': 1951, 'level': 9},
#     {'ability': 6197, 'time': 2021, 'level': 10},
#     {'ability': 6339, 'time': 2201, 'level': 11},
#     {'ability': 8340, 'time': 2236, 'level': 12},
#     {'ability': 6342, 'time': 2279, 'level': 13},
#     {'ability': 6342, 'time': 2439, 'level': 14},
#     {'ability': 6007, 'time': 2683, 'level': 15}],
#    'item_0_name': 'Boots of Speed',
#    'item_1_name': 'Magic Wand',
#    'item_2_name': "Eul's Scepter of Divinity",
#    'item_4_name': 'Town Portal Scroll',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 86725175,
#    'player_slot': 1,
#    'hero_id': 6,
#    'item_0': 63,
#    'item_1': 116,
#    'item_2': 152,
#    'item_3': 263,
#    'item_4': 212,
#    'item_5': 33,
#    'backpack_0': 0,
#    'backpack_1': 46,
#    'backpack_2': 0,
#    'kills': 1,
#    'deaths': 1,
#    'assists': 5,
#    'leaver_status': 0,
#    'last_hits': 284,
#    'denies': 11,
#    'gold_per_min': 581,
#    'xp_per_min': 608,
#    'level': 21,
#    'hero_damage': 7504,
#    'tower_damage': 8246,
#    'hero_healing': 0,
#    'gold': 5086,
#    'gold_spent': 16055,
#    'scaled_hero_damage': 4392,
#    'scaled_tower_damage': 5290,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5019, 'time': 999, 'level': 1},
#     {'ability': 5021, 'time': 1045, 'level': 2},
#     {'ability': 5021, 'time': 1123, 'level': 3},
#     {'ability': 5019, 'time': 1230, 'level': 4},
#     {'ability': 5021, 'time': 1330, 'level': 5},
#     {'ability': 5022, 'time': 1454, 'level': 6},
#     {'ability': 5021, 'time': 1509, 'level': 7},
#     {'ability': 5632, 'time': 1588, 'level': 8},
#     {'ability': 5019, 'time': 1692, 'level': 9},
#     {'ability': 5921, 'time': 1814, 'level': 10},
#     {'ability': 5632, 'time': 1935, 'level': 11},
#     {'ability': 5022, 'time': 1991, 'level': 12},
#     {'ability': 5019, 'time': 2064, 'level': 13},
#     {'ability': 5632, 'time': 2175, 'level': 14},
#     {'ability': 6016, 'time': 2259, 'level': 15},
#     {'ability': 5632, 'time': 2369, 'level': 16},
#     {'ability': 5022, 'time': 2492, 'level': 17},
#     {'ability': 6280, 'time': 2707, 'level': 18}],
#    'hero_name': 'Drow Ranger',
#    'item_0_name': 'Power Treads',
#    'item_1_name': 'Black King Bar',
#    'item_2_name': 'Shadow Blade',
#    'item_3_name': 'Hurricane Pike',
#    'item_4_name': 'Ring of Aquila',
#    'item_5_name': 'Cheese',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 10366616,
#    'player_slot': 2,
#    'hero_id': 63,
#    'item_0': 63,
#    'item_1': 174,
#    'item_2': 36,
#    'item_3': 212,
#    'item_4': 160,
#    'item_5': 114,
#    'backpack_0': 38,
#    'backpack_1': 0,
#    'backpack_2': 46,
#    'kills': 7,
#    'deaths': 0,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 227,
#    'denies': 11,
#    'gold_per_min': 589,
#    'xp_per_min': 689,
#    'level': 23,
#    'hero_damage': 22071,
#    'tower_damage': 5096,
#    'hero_healing': 116,
#    'gold': 1795,
#    'gold_spent': 19140,
#    'scaled_hero_damage': 14952,
#    'scaled_tower_damage': 3255,
#    'scaled_hero_healing': 114,
#    'ability_upgrades': [{'ability': 5290, 'time': 885, 'level': 1},
#     {'ability': 5291, 'time': 1073, 'level': 2},
#     {'ability': 5289, 'time': 1148, 'level': 3},
#     {'ability': 5290, 'time': 1233, 'level': 4},
#     {'ability': 5290, 'time': 1361, 'level': 5},
#     {'ability': 5292, 'time': 1459, 'level': 6},
#     {'ability': 5290, 'time': 1604, 'level': 7},
#     {'ability': 5291, 'time': 1645, 'level': 8},
#     {'ability': 5291, 'time': 1717, 'level': 9},
#     {'ability': 6372, 'time': 1826, 'level': 10},
#     {'ability': 5291, 'time': 1859, 'level': 11},
#     {'ability': 5292, 'time': 2003, 'level': 12},
#     {'ability': 5289, 'time': 2085, 'level': 13},
#     {'ability': 5289, 'time': 2152, 'level': 14},
#     {'ability': 5928, 'time': 2208, 'level': 15},
#     {'ability': 5289, 'time': 2308, 'level': 16},
#     {'ability': 5292, 'time': 2496, 'level': 17},
#     {'ability': 6989, 'time': 2682, 'level': 18}],
#    'hero_name': 'Weaver',
#    'item_0_name': 'Power Treads',
#    'item_1_name': 'Diffusal Blade',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Ring of Aquila',
#    'item_4_name': 'Eye of Skadi',
#    'item_5_name': 'Heart of Tarrasque',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 108452107,
#    'player_slot': 3,
#    'hero_id': 9,
#    'item_0': 212,
#    'item_1': 63,
#    'item_2': 116,
#    'item_3': 158,
#    'item_4': 41,
#    'item_5': 236,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 46,
#    'kills': 7,
#    'deaths': 0,
#    'assists': 4,
#    'leaver_status': 0,
#    'last_hits': 226,
#    'denies': 21,
#    'gold_per_min': 561,
#    'xp_per_min': 461,
#    'level': 18,
#    'hero_damage': 17233,
#    'tower_damage': 5063,
#    'hero_healing': 0,
#    'gold': 3322,
#    'gold_spent': 15800,
#    'scaled_hero_damage': 11359,
#    'scaled_tower_damage': 2999,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5051, 'time': 1018, 'level': 1},
#     {'ability': 5050, 'time': 1046, 'level': 2},
#     {'ability': 5051, 'time': 1120, 'level': 3},
#     {'ability': 5048, 'time': 1195, 'level': 4},
#     {'ability': 5051, 'time': 1277, 'level': 5},
#     {'ability': 5049, 'time': 1394, 'level': 6},
#     {'ability': 5051, 'time': 1470, 'level': 7},
#     {'ability': 5050, 'time': 1531, 'level': 8},
#     {'ability': 5050, 'time': 1625, 'level': 9},
#     {'ability': 5959, 'time': 1737, 'level': 10},
#     {'ability': 5050, 'time': 1854, 'level': 11},
#     {'ability': 5049, 'time': 1917, 'level': 12},
#     {'ability': 5048, 'time': 2045, 'level': 13},
#     {'ability': 5048, 'time': 2176, 'level': 14},
#     {'ability': 6013, 'time': 2315, 'level': 15},
#     {'ability': 5048, 'time': 2418, 'level': 16},
#     {'ability': 5049, 'time': 2755, 'level': 17}],
#    'hero_name': 'Mirana',
#    'item_0_name': 'Ring of Aquila',
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Black King Bar',
#    'item_3_name': 'Mjollnir',
#    'item_4_name': 'Bottle',
#    'item_5_name': 'Dragon Lance',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 47434686,
#    'player_slot': 4,
#    'hero_id': 85,
#    'item_0': 214,
#    'item_1': 265,
#    'item_2': 73,
#    'item_3': 46,
#    'item_4': 36,
#    'item_5': 40,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 188,
#    'kills': 0,
#    'deaths': 4,
#    'assists': 11,
#    'leaver_status': 0,
#    'last_hits': 34,
#    'denies': 6,
#    'gold_per_min': 259,
#    'xp_per_min': 306,
#    'level': 14,
#    'hero_damage': 4035,
#    'tower_damage': 545,
#    'hero_healing': 2701,
#    'gold': 1807,
#    'gold_spent': 7000,
#    'scaled_hero_damage': 3584,
#    'scaled_tower_damage': 281,
#    'scaled_hero_healing': 1387,
#    'ability_upgrades': [{'ability': 5442, 'time': 887, 'level': 1},
#     {'ability': 5443, 'time': 1046, 'level': 2},
#     {'ability': 5444, 'time': 1185, 'level': 3},
#     {'ability': 5444, 'time': 1316, 'level': 4},
#     {'ability': 5444, 'time': 1412, 'level': 5},
#     {'ability': 5447, 'time': 1664, 'level': 6},
#     {'ability': 5444, 'time': 1807, 'level': 7},
#     {'ability': 5443, 'time': 1974, 'level': 8},
#     {'ability': 5443, 'time': 2051, 'level': 9},
#     {'ability': 5911, 'time': 2332, 'level': 10},
#     {'ability': 5443, 'time': 2436, 'level': 11},
#     {'ability': 5447, 'time': 2619, 'level': 12},
#     {'ability': 5442, 'time': 2711, 'level': 13},
#     {'ability': 5442, 'time': 2858, 'level': 14}],
#    'hero_name': 'Undying',
#    'item_0_name': 'Tranquil Boots',
#    'item_1_name': 'Infused Raindrop',
#    'item_2_name': 'Bracer',
#    'item_3_name': 'Town Portal Scroll',
#    'item_4_name': 'Magic Wand',
#    'item_5_name': 'Dust of Appearance',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 137193239,
#    'player_slot': 128,
#    'hero_id': 56,
#    'item_0': 63,
#    'item_1': 116,
#    'item_2': 166,
#    'item_3': 178,
#    'item_4': 46,
#    'item_5': 212,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 2,
#    'deaths': 3,
#    'assists': 1,
#    'leaver_status': 0,
#    'last_hits': 176,
#    'denies': 4,
#    'gold_per_min': 369,
#    'xp_per_min': 421,
#    'level': 17,
#    'hero_damage': 7174,
#    'tower_damage': 2633,
#    'hero_healing': 0,
#    'gold': 1105,
#    'gold_spent': 10560,
#    'scaled_hero_damage': 6087,
#    'scaled_tower_damage': 1609,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5260, 'time': 967, 'level': 1},
#     {'ability': 5261, 'time': 1129, 'level': 2},
#     {'ability': 5260, 'time': 1143, 'level': 3},
#     {'ability': 5259, 'time': 1220, 'level': 4},
#     {'ability': 5260, 'time': 1328, 'level': 5},
#     {'ability': 5262, 'time': 1478, 'level': 6},
#     {'ability': 5259, 'time': 1550, 'level': 7},
#     {'ability': 5259, 'time': 1675, 'level': 8},
#     {'ability': 5259, 'time': 1891, 'level': 9},
#     {'ability': 5260, 'time': 1962, 'level': 10},
#     {'ability': 5261, 'time': 2018, 'level': 11},
#     {'ability': 5262, 'time': 2102, 'level': 12},
#     {'ability': 5261, 'time': 2139, 'level': 13},
#     {'ability': 6299, 'time': 2319, 'level': 14},
#     {'ability': 6104, 'time': 2542, 'level': 15},
#     {'ability': 5261, 'time': 2782, 'level': 16}],
#    'hero_name': 'Clinkz',
#    'item_0_name': 'Power Treads',
#    'item_1_name': 'Black King Bar',
#    'item_2_name': 'Maelstrom',
#    'item_3_name': 'Soul Ring',
#    'item_4_name': 'Town Portal Scroll',
#    'item_5_name': 'Ring of Aquila',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 89423756,
#    'player_slot': 129,
#    'hero_id': 42,
#    'item_0': 1,
#    'item_1': 29,
#    'item_2': 36,
#    'item_3': 0,
#    'item_4': 40,
#    'item_5': 92,
#    'backpack_0': 0,
#    'backpack_1': 216,
#    'backpack_2': 0,
#    'kills': 1,
#    'deaths': 3,
#    'assists': 3,
#    'leaver_status': 0,
#    'last_hits': 89,
#    'denies': 3,
#    'gold_per_min': 217,
#    'xp_per_min': 285,
#    'level': 14,
#    'hero_damage': 2773,
#    'tower_damage': 79,
#    'hero_healing': 1011,
#    'gold': 1335,
#    'gold_spent': 6050,
#    'scaled_hero_damage': 2161,
#    'scaled_tower_damage': 39,
#    'scaled_hero_healing': 398,
#    'ability_upgrades': [{'ability': 5086, 'time': 972, 'level': 1},
#     {'ability': 5088, 'time': 1128, 'level': 2},
#     {'ability': 5087, 'time': 1321, 'level': 3},
#     {'ability': 5086, 'time': 1417, 'level': 4},
#     {'ability': 5086, 'time': 1638, 'level': 5},
#     {'ability': 5089, 'time': 1652, 'level': 6},
#     {'ability': 5086, 'time': 1786, 'level': 7},
#     {'ability': 5088, 'time': 1970, 'level': 8},
#     {'ability': 5088, 'time': 2233, 'level': 9},
#     {'ability': 5088, 'time': 2377, 'level': 10},
#     {'ability': 7107, 'time': 2470, 'level': 11},
#     {'ability': 5089, 'time': 2656, 'level': 12},
#     {'ability': 5087, 'time': 2841, 'level': 13},
#     {'ability': 5087, 'time': 2904, 'level': 14}],
#    'hero_name': 'Wraith King',
#    'item_0_name': 'Blink Dagger',
#    'item_1_name': 'Boots of Speed',
#    'item_2_name': 'Magic Wand',
#    'item_4_name': 'Dust of Appearance',
#    'item_5_name': 'Urn of Shadows',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 113800818,
#    'player_slot': 130,
#    'hero_id': 37,
#    'item_0': 40,
#    'item_1': 16,
#    'item_2': 188,
#    'item_3': 43,
#    'item_4': 0,
#    'item_5': 214,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 0,
#    'deaths': 6,
#    'assists': 3,
#    'leaver_status': 0,
#    'last_hits': 35,
#    'denies': 3,
#    'gold_per_min': 168,
#    'xp_per_min': 186,
#    'level': 11,
#    'hero_damage': 3797,
#    'tower_damage': 200,
#    'hero_healing': 1412,
#    'gold': 76,
#    'gold_spent': 5695,
#    'scaled_hero_damage': 3461,
#    'scaled_tower_damage': 106,
#    'scaled_hero_healing': 811,
#    'ability_upgrades': [{'ability': 5163, 'time': 887, 'level': 1},
#     {'ability': 5162, 'time': 1079, 'level': 2},
#     {'ability': 5163, 'time': 1185, 'level': 3},
#     {'ability': 5162, 'time': 1370, 'level': 4},
#     {'ability': 5164, 'time': 1573, 'level': 5},
#     {'ability': 5165, 'time': 1739, 'level': 6},
#     {'ability': 5164, 'time': 1956, 'level': 7},
#     {'ability': 5164, 'time': 2254, 'level': 8},
#     {'ability': 5164, 'time': 2377, 'level': 9},
#     {'ability': 6056, 'time': 2642, 'level': 10},
#     {'ability': 5162, 'time': 2797, 'level': 11}],
#    'hero_name': 'Warlock',
#    'item_0_name': 'Dust of Appearance',
#    'item_1_name': 'Iron Branch',
#    'item_2_name': 'Smoke of Deceit',
#    'item_3_name': 'Sentry Ward',
#    'item_5_name': 'Tranquil Boots',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 107803494,
#    'player_slot': 131,
#    'hero_id': 19,
#    'item_0': 63,
#    'item_1': 212,
#    'item_2': 127,
#    'item_3': 252,
#    'item_4': 1,
#    'item_5': 36,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 4,
#    'deaths': 2,
#    'assists': 1,
#    'leaver_status': 0,
#    'last_hits': 211,
#    'denies': 25,
#    'gold_per_min': 450,
#    'xp_per_min': 444,
#    'level': 18,
#    'hero_damage': 16537,
#    'tower_damage': 954,
#    'hero_healing': 0,
#    'gold': 3869,
#    'gold_spent': 11275,
#    'scaled_hero_damage': 10668,
#    'scaled_tower_damage': 710,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5108, 'time': 904, 'level': 1},
#     {'ability': 5106, 'time': 1019, 'level': 2},
#     {'ability': 5106, 'time': 1067, 'level': 3},
#     {'ability': 5107, 'time': 1137, 'level': 4},
#     {'ability': 5106, 'time': 1215, 'level': 5},
#     {'ability': 5109, 'time': 1280, 'level': 6},
#     {'ability': 5106, 'time': 1341, 'level': 7},
#     {'ability': 5107, 'time': 1424, 'level': 8},
#     {'ability': 5107, 'time': 1520, 'level': 9},
#     {'ability': 5939, 'time': 1626, 'level': 10},
#     {'ability': 5107, 'time': 1758, 'level': 11},
#     {'ability': 5109, 'time': 1900, 'level': 12},
#     {'ability': 5108, 'time': 2025, 'level': 13},
#     {'ability': 5108, 'time': 2242, 'level': 14},
#     {'ability': 6153, 'time': 2318, 'level': 15},
#     {'ability': 6937, 'time': 2442, 'level': 16},
#     {'ability': 5109, 'time': 2796, 'level': 17}],
#    'hero_name': 'Tiny',
#    'item_0_name': 'Power Treads',
#    'item_1_name': 'Ring of Aquila',
#    'item_2_name': 'Blade Mail',
#    'item_3_name': 'Echo Sabre',
#    'item_4_name': 'Blink Dagger',
#    'item_5_name': 'Magic Wand',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 134276083,
#    'player_slot': 132,
#    'hero_id': 108,
#    'item_0': 231,
#    'item_1': 36,
#    'item_2': 40,
#    'item_3': 0,
#    'item_4': 46,
#    'item_5': 242,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 0,
#    'deaths': 6,
#    'assists': 1,
#    'leaver_status': 0,
#    'last_hits': 190,
#    'denies': 8,
#    'gold_per_min': 379,
#    'xp_per_min': 406,
#    'level': 17,
#    'hero_damage': 10550,
#    'tower_damage': 318,
#    'hero_healing': 1500,
#    'gold': 630,
#    'gold_spent': 11355,
#    'scaled_hero_damage': 6609,
#    'scaled_tower_damage': 177,
#    'scaled_hero_healing': 652,
#    'ability_upgrades': [{'ability': 5615, 'time': 1006, 'level': 1},
#     {'ability': 5613, 'time': 1054, 'level': 2},
#     {'ability': 5613, 'time': 1130, 'level': 3},
#     {'ability': 5615, 'time': 1239, 'level': 4},
#     {'ability': 5613, 'time': 1300, 'level': 5},
#     {'ability': 5615, 'time': 1395, 'level': 6},
#     {'ability': 5613, 'time': 1499, 'level': 7},
#     {'ability': 5614, 'time': 1707, 'level': 8},
#     {'ability': 5615, 'time': 1866, 'level': 9},
#     {'ability': 5616, 'time': 1917, 'level': 10},
#     {'ability': 6967, 'time': 1973, 'level': 11},
#     {'ability': 5614, 'time': 2119, 'level': 12},
#     {'ability': 5614, 'time': 2208, 'level': 13},
#     {'ability': 5614, 'time': 2297, 'level': 14},
#     {'ability': 5616, 'time': 2451, 'level': 15},
#     {'ability': 6003, 'time': 2619, 'level': 16}],
#    'hero_name': 'Underlord',
#    'item_0_name': 'Guardian Greaves',
#    'item_1_name': 'Magic Wand',
#    'item_2_name': 'Dust of Appearance',
#    'item_4_name': 'Town Portal Scroll',
#    'item_5_name': 'Crimson Guard',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'}],
#  'radiant_win': True,
#  'duration': 1956,
#  'pre_game_duration': 90,
#  'start_time': 1534357894,
#  'match_id': 4061804100,
#  'match_seq_num': 3523804965,
#  'tower_status_radiant': 1980,
#  'tower_status_dire': 1536,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 2,
#  'cluster': 113,
#  'first_blood_time': 196,
#  'lobby_type': 1,
#  'human_players': 10,
#  'leagueid': 9870,
#  'positive_votes': 493,
#  'negative_votes': 33,
#  'game_mode': 2,
#  'flags': 1,
#  'engine': 1,
#  'radiant_score': 20,
#  'dire_score': 7,
#  'radiant_team_id': 5228654,
#  'radiant_name': 'VGJ Storm',
#  'radiant_logo': 936056105842781214,
#  'radiant_team_complete': 0,
#  'dire_team_id': 726228,
#  'dire_name': 'Vici Gaming',
#  'dire_logo': 845963870798027729,
#  'dire_team_complete': 1,
#  'radiant_captain': 47434686,
#  'dire_captain': 89423756,
#  'picks_bans': [{'is_pick': False, 'hero_id': 66, 'team': 1, 'order': 0},
#   {'is_pick': False, 'hero_id': 58, 'team': 0, 'order': 1},
#   {'is_pick': False, 'hero_id': 84, 'team': 1, 'order': 2},
#   {'is_pick': False, 'hero_id': 91, 'team': 0, 'order': 3},
#   {'is_pick': False, 'hero_id': 90, 'team': 1, 'order': 4},
#   {'is_pick': False, 'hero_id': 36, 'team': 0, 'order': 5},
#   {'is_pick': True, 'hero_id': 42, 'team': 1, 'order': 6},
#   {'is_pick': True, 'hero_id': 119, 'team': 0, 'order': 7},
#   {'is_pick': True, 'hero_id': 63, 'team': 0, 'order': 8},
#   {'is_pick': True, 'hero_id': 19, 'team': 1, 'order': 9},
#   {'is_pick': False, 'hero_id': 59, 'team': 1, 'order': 10},
#   {'is_pick': False, 'hero_id': 12, 'team': 0, 'order': 11},
#   {'is_pick': False, 'hero_id': 92, 'team': 1, 'order': 12},
#   {'is_pick': False, 'hero_id': 61, 'team': 0, 'order': 13},
#   {'is_pick': True, 'hero_id': 85, 'team': 0, 'order': 14},
#   {'is_pick': True, 'hero_id': 37, 'team': 1, 'order': 15},
#   {'is_pick': True, 'hero_id': 9, 'team': 0, 'order': 16},
#   {'is_pick': True, 'hero_id': 56, 'team': 1, 'order': 17},
#   {'is_pick': False, 'hero_id': 10, 'team': 0, 'order': 18},
#   {'is_pick': False, 'hero_id': 113, 'team': 1, 'order': 19},
#   {'is_pick': True, 'hero_id': 108, 'team': 1, 'order': 20},
#   {'is_pick': True, 'hero_id': 6, 'team': 0, 'order': 21}],
#  'lobby_name': 'Practice',
#  'game_mode_name': 'Captains Mode',
#  'cluster_name': 'US West'}
