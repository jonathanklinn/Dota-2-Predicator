# %%
import dota2api
import numpy as np
import pandas as pd

# %%
api = dota2api.Initialise("B335AEF628EF2F2D2DC5A94BA4A02ED9")

mf =api.get_match_details(3917076539)

# %%
mf
# Out:
# {'players': [{'account_id': 84853828,
#    'player_slot': 0,
#    'hero_id': 86,
#    'item_0': 180,
#    'item_1': 46,
#    'item_2': 1,
#    'item_3': 34,
#    'item_4': 0,
#    'item_5': 37,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 3,
#    'deaths': 5,
#    'assists': 19,
#    'leaver_status': 0,
#    'last_hits': 58,
#    'denies': 1,
#    'gold_per_min': 310,
#    'xp_per_min': 370,
#    'level': 16,
#    'hero_name': 'Rubick',
#    'item_0_name': 'Arcane Boots',
#    'item_1_name': 'Town Portal Scroll',
#    'item_2_name': 'Blink Dagger',
#    'item_3_name': 'Magic Stick',
#    'item_5_name': 'Ghost Scepter',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 117956848,
#    'player_slot': 1,
#    'hero_id': 120,
#    'item_0': 41,
#    'item_1': 180,
#    'item_2': 125,
#    'item_3': 36,
#    'item_4': 1,
#    'item_5': 100,
#    'backpack_0': 46,
#    'backpack_1': 0,
# ...

# %%
mf['barracks_status_radiant']
dire_assists=0

mf['']

# %%
dire_assists+= mf['players'][0]['assists']
dire_assists
# Out:
# 104

# %%
dire_assists+= mf['players'][1]['assists']
dire_assists+= mf['players'][2]['assists']
dire_assists+= mf['players'][3]['assists']
dire_assists+= mf['players'][4]['assists']
dire_assists+= mf['players'][5]['assists']

# %%
dire_assists
# Out:
# 198
